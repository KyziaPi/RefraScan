# %%
# IMPORTANT:
# This notebook is for visualization of the finalized results only.
# It does not retrain the model or perform a new evaluation.
# Values below were taken from the finalized final-model-experiment-6 run.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ============================================================
# FINAL DEVELOPMENT / CROSS-VALIDATION RESULTS
# Source: final-model-experiment-6.ipynb
# This notebook only visualizes finalized results.
# It does NOT retrain or reevaluate the model.
# ============================================================

cv_results = pd.DataFrame({
    "Metric": [
        "Accuracy",
        "Balanced Accuracy",
        "Macro Precision",
        "Macro Recall",
        "Macro F1"
    ],
    "Image Only": [
        0.7432,
        0.6523,
        0.6034,
        0.6523,
        0.6077
    ],
    "Image + Age": [
        0.7464,
        0.6538,
        0.6082,
        0.6538,
        0.6145
    ]
})

cv_results
# Out:
#               Metric  Image Only  Image + Age
# 0           Accuracy      0.7432       0.7464
# 1  Balanced Accuracy      0.6523       0.6538
# 2    Macro Precision      0.6034       0.6082
# 3       Macro Recall      0.6523       0.6538
# 4           Macro F1      0.6077       0.6145

# %%
# ============================================================
# DEVELOPMENT / CROSS-VALIDATION PERFORMANCE COMPARISON
# ============================================================

x = np.arange(len(cv_results["Metric"]))
width = 0.35

fig, ax = plt.subplots(figsize=(11, 6))

bars1 = ax.bar(
    x - width/2,
    cv_results["Image Only"],
    width,
    label="Image Only"
)

bars2 = ax.bar(
    x + width/2,
    cv_results["Image + Age"],
    width,
    label="Image + Age"
)

ax.set_title(
    "ResNet50 Development Performance: Image Only vs Image + Age",
    fontsize=14,
    fontweight="bold"
)

ax.set_ylabel("Score")
ax.set_xticks(x)
ax.set_xticklabels(cv_results["Metric"], rotation=20, ha="right")
ax.set_ylim(0, 0.85)

ax.legend()
ax.grid(axis="y", alpha=0.3)

# Add values above all bars
for bars in [bars1, bars2]:
    for bar in bars:
        value = bar.get_height()
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            value + 0.015,
            f"{value:.4f}",
            ha="center",
            va="bottom",
            fontsize=9
        )

plt.tight_layout()
plt.show()

# %%
# ============================================================
# FINAL HOLDOUT EVALUATION RESULTS
# Source: final-model-experiment-6.ipynb
# Final configuration: ResNet50 Image + Age
# ============================================================

holdout_metrics = pd.DataFrame({
    "Metric": [
        "Accuracy",
        "Balanced Accuracy",
        "Macro Precision",
        "Macro Recall",
        "Macro F1"
    ],
    "Score": [
        0.7013,
        0.6374,
        0.6219,
        0.6374,
        0.6244
    ]
})

holdout_metrics
# Out:
#               Metric   Score
# 0           Accuracy  0.7013
# 1  Balanced Accuracy  0.6374
# 2    Macro Precision  0.6219
# 3       Macro Recall  0.6374
# 4           Macro F1  0.6244

# %%
# ============================================================
# FINAL HOLDOUT PERFORMANCE
# ============================================================

fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.bar(
    holdout_metrics["Metric"],
    holdout_metrics["Score"]
)

ax.set_title(
    "Final ResNet50 Image + Age Holdout Performance",
    fontsize=14,
    fontweight="bold"
)

ax.set_ylabel("Score")
ax.set_ylim(0, 0.8)

ax.tick_params(axis="x", rotation=20)
ax.grid(axis="y", alpha=0.3)

# Add values above all bars
for bar in bars:
    value = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.015,
        f"{value:.4f}",
        ha="center",
        va="bottom",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
# ============================================================
# FINAL HOLDOUT CLASSIFICATION REPORT
# Source: final-model-experiment-6.ipynb
# ============================================================

classification_results = pd.DataFrame({
    "Class": [
        "Emmetropia",
        "Myopia",
        "Hyperopia"
    ],
    "Precision": [
        0.42,
        0.86,
        0.59
    ],
    "Recall": [
        0.37,
        0.77,
        0.77
    ],
    "F1-Score": [
        0.39,
        0.81,
        0.67
    ]
})

classification_results
# Out:
#         Class  Precision  Recall  F1-Score
# 0  Emmetropia       0.42    0.37      0.39
# 1      Myopia       0.86    0.77      0.81
# 2   Hyperopia       0.59    0.77      0.67

# %%
# ============================================================
# CLASS-SPECIFIC HOLDOUT PERFORMANCE
# ============================================================

x = np.arange(len(classification_results["Class"]))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

bars1 = ax.bar(
    x - width,
    classification_results["Precision"],
    width,
    label="Precision"
)

bars2 = ax.bar(
    x,
    classification_results["Recall"],
    width,
    label="Recall"
)

bars3 = ax.bar(
    x + width,
    classification_results["F1-Score"],
    width,
    label="F1-Score"
)

ax.set_title(
    "Final ResNet50 Image + Age Class-Specific Performance",
    fontsize=14,
    fontweight="bold"
)

ax.set_ylabel("Score")
ax.set_xticks(x)
ax.set_xticklabels(classification_results["Class"])
ax.set_ylim(0, 1.0)

ax.legend()
ax.grid(axis="y", alpha=0.3)

# Add values above all bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        value = bar.get_height()
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            value + 0.015,
            f"{value:.2f}",
            ha="center",
            va="bottom",
            fontsize=9
        )

plt.tight_layout()
plt.show()

# %%
# ============================================================
# FINAL HOLDOUT CONFUSION MATRIX
# Source: final-model-experiment-6.ipynb
# ============================================================

confusion_matrix = np.array([
    [10, 5, 12],
    [11, 68, 9],
    [3, 6, 30]
])

class_names = [
    "Emmetropia",
    "Myopia",
    "Hyperopia"
]

# %%
# ============================================================
# CONFUSION MATRIX VISUALIZATION
# ============================================================

fig, ax = plt.subplots(figsize=(8, 7))

sns.heatmap(
    confusion_matrix,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names,
    cbar=False,
    ax=ax
)

ax.set_title(
    "Final ResNet50 Image + Age Confusion Matrix",
    fontsize=14,
    fontweight="bold"
)

ax.set_xlabel("Predicted Class")
ax.set_ylabel("Actual Class")

plt.tight_layout()
plt.show()

# %%
# ============================================================
# DEVELOPMENT CROSS-VALIDATION VS FINAL HOLDOUT PERFORMANCE
# ============================================================
# Development results:
# ResNet50 Image + Age, 10-fold Stratified Group CV
#
# Holdout results:
# Final ResNet50 Image + Age model
# 15% untouched patient-level holdout set
#
# This notebook only visualizes finalized results.
# It does NOT retrain or reevaluate the model.
# ============================================================

comparison_results = pd.DataFrame({
    "Metric": [
        "Accuracy",
        "Balanced Accuracy",
        "Macro Precision",
        "Macro Recall",
        "Macro F1"
    ],
    "Development CV": [
        0.7464,
        0.6538,
        0.6082,
        0.6538,
        0.6145
    ],
    "Final Holdout": [
        0.7013,
        0.6374,
        0.6219,
        0.6374,
        0.6244
    ]
})

comparison_results
# Out:
#               Metric  Development CV  Final Holdout
# 0           Accuracy          0.7464         0.7013
# 1  Balanced Accuracy          0.6538         0.6374
# 2    Macro Precision          0.6082         0.6219
# 3       Macro Recall          0.6538         0.6374
# 4           Macro F1          0.6145         0.6244

# %%
# ============================================================
# DEVELOPMENT CV VS FINAL HOLDOUT PERFORMANCE
# ============================================================

x = np.arange(len(comparison_results["Metric"]))
width = 0.35

fig, ax = plt.subplots(figsize=(11, 6))

ax.bar(
    x - width/2,
    comparison_results["Development CV"],
    width,
    label="Development Cross-Validation"
)

ax.bar(
    x + width/2,
    comparison_results["Final Holdout"],
    width,
    label="Final Holdout Test"
)

ax.set_title(
    "Development Cross-Validation vs Final Holdout Test Performance",
    fontsize=14,
    fontweight="bold"
)

ax.set_ylabel("Score")
ax.set_xticks(x)
ax.set_xticklabels(
    comparison_results["Metric"],
    rotation=20,
    ha="right"
)

ax.set_ylim(0, 0.85)

ax.legend()
ax.grid(axis="y", alpha=0.3)

# Add values above bars
for i in range(len(comparison_results)):
    ax.text(
        i - width/2,
        comparison_results["Development CV"][i] + 0.015,
        f"{comparison_results['Development CV'][i]:.4f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

    ax.text(
        i + width/2,
        comparison_results["Final Holdout"][i] + 0.015,
        f"{comparison_results['Final Holdout'][i]:.4f}",
        ha="center",
        va="bottom",
        fontsize=9
    )

plt.tight_layout()
plt.show()
