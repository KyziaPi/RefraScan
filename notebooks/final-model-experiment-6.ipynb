# %%
import os
import sys
import logging
import random
import numpy as np

# Keep Kaggle output readable while TensorFlow initializes.
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=0"

import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)
logging.getLogger("tensorflow").setLevel(logging.FATAL)

import tensorflow as tf

# Fixed seeds make the comparison as reproducible as practical.
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# -----------------------------------------------------------------------------
# REPOSITORY CONFIGURATION
# -----------------------------------------------------------------------------
REPO_NAME = "RefraScan"
GITHUB_USER = "KyziaPi"
BRANCH_NAME = "Model-Experiment"  # Change to the branch containing the finalized VSCode code.
REPO_URL = f"https://github.com/{GITHUB_USER}/{REPO_NAME}.git"
REPO_PATH = os.path.join("/kaggle/working", REPO_NAME)

if not os.path.exists(REPO_PATH):
    # !env GIT_TERMINAL_PROMPT=0 git clone -b {BRANCH_NAME} {REPO_URL}
else:
    # !cd {REPO_PATH} && env GIT_TERMINAL_PROMPT=0 git fetch --all && git checkout {BRANCH_NAME} && git pull origin {BRANCH_NAME}

if REPO_PATH not in sys.path:
    sys.path.append(REPO_PATH)

import sys
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess
from tensorflow.keras.applications.densenet import preprocess_input as densenet_preprocess

from src.preprocessing import load_and_clean_data, encode_target, validate_dataset
from src.cross_validation import (
    split_holdout_test,
    run_cross_validation,
    train_final_on_development,
    evaluate_holdout_once,
)
from src.models import build_model
# Out:
# Cloning into 'RefraScan'...
# remote: Enumerating objects: 588, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 588 (delta 1), reused 3 (delta 1), pack-reused 580 (from 1)
# Receiving objects: 100% (588/588), 56.71 MiB | 34.34 MiB/s, done.
# Resolving deltas: 100% (332/332), done.

# %%
# -----------------------------------------------------------------------------
# FINAL EXPERIMENT CONFIGURATION
# -----------------------------------------------------------------------------
# Set this ONLY after comparing EfficientNetB3, ResNet50, and DenseNet121
# using their image-only 10-fold CV results.
BEST_MODEL_NAME = "resnet50"  # Change after the controlled comparison.

PREPROCESS_INPUT = {
    "efficientnet": efficientnet_preprocess,
    "resnet50": resnet_preprocess,
    "densenet121": densenet_preprocess,
}[BEST_MODEL_NAME]

DATASET_DIR = '/kaggle/input/datasets/yerikaelainegueco/fundus-images-with-refractive-values'
CSV_PATH = os.path.join(DATASET_DIR, 'RefraScan_dataset.csv')
IMG_DIR = os.path.join(DATASET_DIR, 'FundusImages')

df = load_and_clean_data(CSV_PATH, IMG_DIR)

print("Dataset columns:")
print(df.columns.tolist())
print("\nData origin distribution:")
print(df["data_origin"].value_counts())

df = validate_dataset(df, patient_col="ID", target_col="classification")
df = encode_target(df)

# Recreate the fixed 15% holdout using the same random seed.
development_df, holdout_df = split_holdout_test(
    df, patient_col="ID", target_col="classification_encoded", test_size=0.15
)

print("\nHoldout data origins:")
print(holdout_df["data_origin"].value_counts())

print(f"Selected architecture: {BEST_MODEL_NAME}")
# Out:
# Dataset columns:
# ['ID', 'sphere', 'cylinder', 'spherical_equivalent', 'age', 'classification', 'eye_side', 'data_origin', 'full_path']
#
# Data origin distribution:
# data_origin
# AUFMC - Lasik    560
# PAPILA           458
# Name: count, dtype: int64
#
# ======================================================================
# DATASET VALIDATION
# ======================================================================
#
# Total records       : 1,018
# Unique patients     : 517
# Missing patient IDs : 0
# Missing labels      : 0
# Duplicate rows      : 0
#
# Class distribution:
# classification
# Myopia        660
# Hyperopia     236
# Emmetropia    122
# Name: count, dtype: int64
#
# Patients with multiple target classes: 50
# These patients have different classifications between their eyes. This is allowed.
#
# Example mixed-class patients:
#  ID classification
#   2     Emmetropia
#   2         Myopia
#   4     Emmetropia
#   4      Hyperopia
#   7     Emmetropia
#   7         Myopia
#  14         Myopia
#  14     Emmetropia
#  19     Emmetropia
#  19      Hyperopia
#  24      Hyperopia
#  24     Emmetropia
#  27     Emmetropia
#  27         Myopia
#  34     Emmetropia
#  34      Hyperopia
#  42     Emmetropia
#  42         Myopia
#  44         Myopia
#  44      Hyperopia
#
# Valid target classes confirmed:
# ['Emmetropia', 'Hyperopia', 'Myopia']
#
# Target-derived refractive measurement columns detected:
#   - sphere
#   - cylinder
#   - spherical_equivalent
#
# These columns will NOT be used as model inputs.
#
# ----------------------------------------------------------------------
# DATASET VALIDATION COMPLETE
# ----------------------------------------------------------------------
# Patient-level grouping will be enforced during all development/holdout splits.
# Mixed eye-level classifications within a patient are allowed.
#
# ======================================================================
# PATIENT-LEVEL HOLDOUT SPLIT
# ======================================================================
# Development records : 864
# Holdout records     : 154
# Development patients: 439
# Holdout patients    : 78
# Patient overlap     : 0
#
# The holdout set is now untouched and will not be used for architecture/model selection.
#
# Holdout data origins:
# data_origin
# PAPILA           78
# AUFMC - Lasik    76
# Name: count, dtype: int64
# Selected architecture: resnet50

# %%
# -----------------------------------------------------------------------------
# PROGRESSIVE FINE-TUNING OF THE SELECTED IMAGE-ONLY ARCHITECTURE
# -----------------------------------------------------------------------------
# Stage 1: unfreeze the upper 10 non-BatchNorm layers.
# Stage 2: expand to the upper 30 non-BatchNorm layers.
# Both stages use the same folds and a low learning rate of 1e-5.

fine_tuned_results = run_cross_validation(
    df=df,
    model_name=BEST_MODEL_NAME,
    preprocess_input=PREPROCESS_INPUT,
    patient_col="ID",
    target_col="classification_encoded",
    n_splits=10,
    batch_size=16,
    epochs=30,
    learning_rate=1e-4,
    use_metadata=False,
    output_dir=f"/kaggle/working/{REPO_NAME}/artifacts/fine_tuning",
    fine_tune=True,
    fine_tune_epochs=10,
    fine_tune_learning_rate=1e-5,
    fine_tune_stages=[10, 30],
)

fine_tuned_results["fold_results"].to_csv(
    f"/kaggle/working/{REPO_NAME}/final_image_only_finetuned_cv_results.csv",
    index=False,
)
# Out:
# ======================================================================
# PATIENT-LEVEL HOLDOUT SPLIT
# ======================================================================
# Development records : 864
# Holdout records     : 154
# Development patients: 439
# Holdout patients    : 78
# Patient overlap     : 0
#
# The holdout set is now untouched and will not be used for architecture/model selection.
#
# ======================================================================
# RESNET50 | IMAGE ONLY
# 10-FOLD STRATIFIED GROUP CROSS-VALIDATION
# ======================================================================
#
# --- Fold 1/10 ---
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788015958.678510     121 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1788015958.681353     121 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/30
#  2/49 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.2969 - loss: 0.7827
# I0000 00:00:1788015978.734833     196 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.4708 - loss: 0.8263
# Epoch 1: val_loss improved from None to 0.43112, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_1_frozen.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_1_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 374ms/step - accuracy: 0.7362 - loss: 0.2758 - val_accuracy: 0.7241 - val_loss: 0.5877
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# --- Running Inference ---
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78e3b9df1e40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.40      0.18      0.25        11
#       Myopia       0.98      0.82      0.90        57
#    Hyperopia       0.50      0.89      0.64        19
#
#     accuracy                           0.76        87
#    macro avg       0.63      0.63      0.60        87
# weighted avg       0.80      0.76      0.76        87
#
# --- Evaluation Metrics ---
# Accuracy          : 0.7586
# Balanced Accuracy : 0.6337
# Macro Precision   : 0.6264
# Macro Recall      : 0.6337
# Macro F1          : 0.5956
#
# Confusion Matrix:
# [[ 2  1  8]
#  [ 1 47  9]
#  [ 2  0 17]]
#
# --- Fold 4/10 ---
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.4799 - loss: 1.1215
# Epoch 1: val_loss improved from None to 0.27324, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_frozen.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 45s 700ms/step - accuracy: 0.5180 - loss: 0.8414 - val_accuracy: 0.6744 - val_loss: 0.2732
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6220 - loss: 0.5670
# Epoch 2: val_loss improved from 0.27324 to 0.21322, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_frozen.keras
#
# Epoch 2: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 426ms/step - accuracy: 0.6414 - loss: 0.4920 - val_accuracy: 0.7674 - val_loss: 0.2132
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.6495 - loss: 0.4238
# Epoch 3: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 393ms/step - accuracy: 0.6581 - loss: 0.4419 - val_accuracy: 0.6163 - val_loss: 0.3187
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6064 - loss: 0.4447
# Epoch 4: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.6414 - loss: 0.4270 - val_accuracy: 0.7326 - val_loss: 0.2413
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.6693 - loss: 0.3842
# Epoch 5: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 413ms/step - accuracy: 0.6658 - loss: 0.3832 - val_accuracy: 0.7209 - val_loss: 0.2355
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.6294 - loss: 0.4240
# Epoch 6: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 431ms/step - accuracy: 0.6825 - loss: 0.3699 - val_accuracy: 0.7674 - val_loss: 0.2140
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6676 - loss: 0.3560
# Epoch 7: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 390ms/step - accuracy: 0.6620 - loss: 0.3652 - val_accuracy: 0.7093 - val_loss: 0.2511
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6900 - loss: 0.3391
# Epoch 8: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 851ms/step - accuracy: 0.6658 - loss: 0.3632 - val_accuracy: 0.6744 - val_loss: 0.2329
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.7179 - loss: 0.3278
# Epoch 9: val_loss did not improve from 0.21322
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - accuracy: 0.7057 - loss: 0.3333 - val_accuracy: 0.7442 - val_loss: 0.2297
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# Fine-tuning stage 1: upper 10 backbone layers...
# Fine-tuning resnet50: unfroze the upper 10 non-BatchNorm backbone layers.
# Epoch 1/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.6802 - loss: 0.4373
# Epoch 1: val_loss improved from None to 0.25000, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 46s 701ms/step - accuracy: 0.6568 - loss: 0.4701 - val_accuracy: 0.6977 - val_loss: 0.2500
# Epoch 2/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.6417 - loss: 0.4133
# Epoch 2: val_loss improved from 0.25000 to 0.22962, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
#
# Epoch 2: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 423ms/step - accuracy: 0.6568 - loss: 0.4043 - val_accuracy: 0.7209 - val_loss: 0.2296
# Epoch 3/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6837 - loss: 0.3686
# Epoch 3: val_loss did not improve from 0.22962
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 414ms/step - accuracy: 0.6799 - loss: 0.3821 - val_accuracy: 0.6744 - val_loss: 0.2376
# Epoch 4/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.6496 - loss: 0.3928
# Epoch 4: val_loss improved from 0.22962 to 0.22879, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
#
# Epoch 4: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 431ms/step - accuracy: 0.6799 - loss: 0.3557 - val_accuracy: 0.7209 - val_loss: 0.2288
# Epoch 5/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.6883 - loss: 0.3647
# Epoch 5: val_loss improved from 0.22879 to 0.22030, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
#
# Epoch 5: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_4_stage_1.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 417ms/step - accuracy: 0.6799 - loss: 0.3847 - val_accuracy: 0.7442 - val_loss: 0.2203
# Epoch 6/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.6821 - loss: 0.3369
# Epoch 6: val_loss did not improve from 0.22030
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s
val_loss did not improve from 0.31944
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 346ms/step - accuracy: 0.7716 - loss: 0.2620 - val_accuracy: 0.6854 - val_loss: 0.3269
# Epoch 6/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.7664 - loss: 0.2623
# Epoch 6: val_loss did not improve from 0.31944
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 350ms/step - accuracy: 0.7742 - loss: 0.2531 - val_accuracy: 0.6966 - val_loss: 0.3283
# Epoch 7/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.7638 - loss: 0.2345
# Epoch 7: val_loss did not improve from 0.31944
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 355ms/step - accuracy: 0.7535 - loss: 0.2433 - val_accuracy: 0.6629 - val_loss: 0.3338
# Epoch 8/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7922 - loss: 0.2315
# Epoch 8: val_loss improved from 0.31944 to 0.31883, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_10_stage_1.keras
#
# Epoch 8: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_10_stage_1.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.7845 - loss: 0.2393 - val_accuracy: 0.7079 - val_loss: 0.3188
# Epoch 9/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.7738 - loss: 0.2317
# Epoch 9: val_loss improved from 0.31883 to 0.30547, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_10_stage_1.keras
#
# Epoch 9: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_10_stage_1.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 362ms/step - accuracy: 0.7729 - loss: 0.2343 - val_accuracy: 0.7079 - val_loss: 0.3055
# Epoch 10/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7698 - loss: 0.2518
# Epoch 10: val_loss did not improve from 0.30547
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.7755 - loss: 0.2474 - val_accuracy: 0.6966 - val_loss: 0.3116
# Restoring model weights from the end of the best epoch: 9.
#
# Fine-tuning stage 2: upper 30 backbone layers...
# Fine-tuning resnet50: unfroze the upper 30 non-BatchNorm backbone layers.
# Epoch 1/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7911 - loss: 0.2461
# Epoch 1: val_loss improved from None to 0.27974, saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_10_stage_2.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/fine_tuning/resnet50_image_fold_10_stage_2.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 49s 700ms/step - accuracy: 0.7445 - loss: 0.2874 - val_accuracy: 0.6966 - val_loss: 0.2797
# Epoch 2/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.7935 - loss: 0.2189
# Epoch 2: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 364ms/step - accuracy: 0.7845 - loss: 0.2318 - val_accuracy: 0.7303 - val_loss: 0.3126
# Epoch 3/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8140 - loss: 0.2247
# Epoch 3: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 365ms/step - accuracy: 0.8026 - loss: 0.2342 - val_accuracy: 0.6517 - val_loss: 0.3436
# Epoch 4/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.7815 - loss: 0.2494
# Epoch 4: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.7729 - loss: 0.2479 - val_accuracy: 0.6742 - val_loss: 0.3130
# Epoch 5/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.7997 - loss: 0.2120
# Epoch 5: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 402ms/step - accuracy: 0.7974 - loss: 0.2180 - val_accuracy: 0.6966 - val_loss: 0.2894
# Epoch 6/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.8061 - loss: 0.2059
# Epoch 6: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 392ms/step - accuracy: 0.7961 - loss: 0.2190 - val_accuracy: 0.7191 - val_loss: 0.3042
# Epoch 7/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7957 - loss: 0.2001
# Epoch 7: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 425ms/step - accuracy: 0.8155 - loss: 0.1893 - val_accuracy: 0.7191 - val_loss: 0.3257
# Epoch 8/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8539 - loss: 0.1831
# Epoch 8: val_loss did not improve from 0.27974
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 395ms/step - accuracy: 0.8413 - loss: 0.1885 - val_accuracy: 0.7191 - val_loss: 0.3479
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# --- Running Inference ---
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.33      0.44      0.38         9
#       Myopia       0.92      0.76      0.83        63
#    Hyperopia       0.40      0.59      0.48        17
#
#     accuracy                           0.70        89
#    macro avg       0.55      0.60      0.56        89
# weighted avg       0.76      0.70      0.72        89
#
# --- Evaluation Metrics ---
# Accuracy          : 0.6966
# Balanced Accuracy : 0.5982
# Macro Precision   : 0.5521
# Macro Recall      : 0.5982
# Macro F1          : 0.5640
#
# Confusion Matrix:
# [[ 4  0  5]
#  [ 5 48 10]
#  [ 3  4 10]]
#
# ======================================================================
# RESNET50 | IMAGE ONLY CV SUMMARY
# ======================================================================
#  Fold    Model  Accuracy  Balanced Accuracy  Macro Precision  Macro Recall  Macro F1  Emmetropia Precision  Emmetropia Recall  Emmetropia F1  Myopia Precision  Myopia Recall  Myopia F1  Hyperopia Precision  Hyperopia Recall  Hyperopia F1
#     1 resnet50  0.752941           0.725275         0.659963      0.725275  0.660714              0.294118           0.714286       0.416667          0.913043       0.807692   0.857143             0.772727          0.653846      0.708333
#     2 resnet50  0.752941           0.737160         0.604630      0.737160  0.633543              0.300000           0.750000       0.428571          0.958333       0.779661   0.859813             0.555556          0.681818      0.612245
#     3 resnet50  0.758621           0.633705         0.626389      0.633705  0.595583              0.400000           0.181818       0.250000          0.979167       0.824561   0.895238             0.500000          0.894737      0.641509
#     4 resnet50  0.802326           0.570405         0.525253      0.570405  0.532187              0.000000           0.000000       0.000000          1.000000       0.806452   0.892857             0.575758          0.904762      0.703704
#     5 resnet50  0.758621           0.670599         0.625000      0.670599  0.636771              0.333333           0.500000       0.400000          1.000000       0.827586   0.905660             0.541667          0.684211      0.604651
#     6 resnet50  0.758621           0.625419         0.617949      0.625419  0.616431              0.200000           0.300000       0.240000          1.000000       0.867925   0.929293             0.653846          0.708333      0.680000
#     7 resnet50  0.697674           0.597701         0.558761      0.597701  0.558539              0.384615           0.714286       0.500000          0.958333       0.793103   0.867925             0.333333          0.285714      0.307692
#     8 resnet50  0.727273           0.715388         0.669030      0.715388  0.673273              0.481481           0.812500       0.604651          0.975610       0.754717   0.851064             0.550000          0.578947      0.564103
#     9 resnet50  0.726190           0.649355         0.594497      0.649355  0.605630              0.285714           0.363636       0.320000          0.977778       0.771930   0.862745             0.520000          0.812500      0.634146
#    10 resnet50  0.696629           0.598195         0.552137      0.598195  0.563975              0.333333           0.444444       0.380952          0.923077       0.761905   0.834783             0.400000          0.588235      0.476190
# Macro F1            : 0.6077 ± 0.0435
# Balanced Accuracy   : 0.6523 ± 0.0553
# Macro Precision     : 0.6034 ± 0.0442
# Macro Recall        : 0.6523 ± 0.0553
# Accuracy            : 0.7432 ± 0.0303

# %%
# -----------------------------------------------------------------------------
# ABLATION: FUNDUS IMAGE ONLY VS FUNDUS IMAGE + AGE
# -----------------------------------------------------------------------------
# Age is the ONLY additional feature tested here.
# Sphere, cylinder, and spherical equivalent remain excluded because they
# determine the refractive-error target.

age_results = run_cross_validation(
    df=df,
    model_name=BEST_MODEL_NAME,
    preprocess_input=PREPROCESS_INPUT,
    patient_col="ID",
    target_col="classification_encoded",
    n_splits=10,
    batch_size=16,
    epochs=30,
    learning_rate=1e-4,
    use_metadata=True,
    metadata_cols=["age_scaled"],
    output_dir=f"/kaggle/working/{REPO_NAME}/artifacts/age_ablation",
    fine_tune=False,
)

age_results["fold_results"].to_csv(
    f"/kaggle/working/{REPO_NAME}/image_plus_age_cv_results.csv",
    index=False,
)

print("\nCompare the Macro F1 and balanced accuracy means above before choosing the final configuration.")
# Out:
# ======================================================================
# PATIENT-LEVEL HOLDOUT SPLIT
# ======================================================================
# Development records : 864
# Holdout records     : 154
# Development patients: 439
# Holdout patients    : 78
# Patient overlap     : 0
#
# The holdout set is now untouched and will not be used for architecture/model selection.
#
# ======================================================================
# RESNET50 | IMAGE + AGE
# 10-FOLD STRATIFIED GROUP CROSS-VALIDATION
# ======================================================================
#
# --- Fold 1/10 ---
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 4.
#
# --- Running Inference ---
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.41      0.64      0.50        11
#       Myopia       0.94      0.82      0.88        57
#    Hyperopia       0.65      0.68      0.67        19
#
#     accuracy                           0.77        87
#    macro avg       0.67      0.72      0.68        87
# weighted avg       0.81      0.77      0.78        87
#
# --- Evaluation Metrics ---
# Accuracy          : 0.7701
# Balanced Accuracy : 0.7150
# Macro Precision   : 0.6673
# Macro Recall      : 0.7150
# Macro F1          : 0.6817
#
# Confusion Matrix:
# [[ 7  2  2]
#  [ 5 47  5]
#  [ 5  1 13]]
#
# --- Fold 4/10 ---
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.4310 - loss: 0.8650
# Epoch 1: val_loss improved from None to 0.26377, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 45s 685ms/step - accuracy: 0.5296 - loss: 0.6819 - val_accuracy: 0.6860 - val_loss: 0.2638
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.5997 - loss: 0.4823
# Epoch 2: val_loss improved from 0.26377 to 0.23723, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
#
# Epoch 2: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 400ms/step - accuracy: 0.6362 - loss: 0.4596 - val_accuracy: 0.6744 - val_loss: 0.2372
# Epoch 3/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5988 - loss: 0.4612
# Epoch 3: val_loss did not improve from 0.23723
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 362ms/step - accuracy: 0.6183 - loss: 0.4320 - val_accuracy: 0.6395 - val_loss: 0.2595
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.6460 - loss: 0.3955
# Epoch 4: val_loss did not improve from 0.23723
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 375ms/step - accuracy: 0.6504 - loss: 0.3991 - val_accuracy: 0.6163 - val_loss: 0.2622
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.6877 - loss: 0.3628
# Epoch 5: val_loss improved from 0.23723 to 0.21392, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
#
# Epoch 5: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - accuracy: 0.6722 - loss: 0.3686 - val_accuracy: 0.7674 - val_loss: 0.2139
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.7024 - loss: 0.3328
# Epoch 6: val_loss did not improve from 0.21392
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 348ms/step - accuracy: 0.6928 - loss: 0.3437 - val_accuracy: 0.7674 - val_loss: 0.2173
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.6987 - loss: 0.3179
# Epoch 7: val_loss improved from 0.21392 to 0.20568, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
#
# Epoch 7: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_4_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - accuracy: 0.6864 - loss: 0.3345 - val_accuracy: 0.8140 - val_loss: 0.2057
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6835 - loss: 0.3406
# Epoch 8: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 344ms/step - accuracy: 0.6915 - loss: 0.3387 - val_accuracy: 0.8140 - val_loss: 0.2104
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.6978 - loss: 0.3286
# Epoch 9: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 359ms/step - accuracy: 0.6928 - loss: 0.3337 - val_accuracy: 0.7907 - val_loss: 0.2096
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.6776 - loss: 0.3369
# Epoch 10: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 362ms/step - accuracy: 0.6928 - loss: 0.3298 - val_accuracy: 0.7442 - val_loss: 0.2245
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6999 - loss: 0.3377
# Epoch 11: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 0.7134 - loss: 0.3331 - val_accuracy: 0.7209 - val_loss: 0.2410
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.6822 - loss: 0.3369
# Epoch 12: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 364ms/step - accuracy: 0.6761 - loss: 0.3259 - val_accuracy: 0.6977 - val_loss: 0.2291
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6848 - loss: 0.3127
# Epoch 13: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.6799 - loss: 0.3270 - val_accuracy: 0.7326 - val_loss: 0.2258
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7147 - loss: 0.3180
# Epoch 14: val_loss did not improve from 0.20568
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 366ms/step - accuracy: 0.7134 - loss: 0.3206 - val_accuracy: 0.7442 - val_loss: 0.2230
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
# --- Running Inference ---
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.12      0.33      0.18         3
#       Myopia       1.00      0.81      0.89        62
#    Hyperopia       0.68      0.90      0.78        21
#
#     accuracy                           0.81        86
#    macro avg       0.60      0.68      0.62        86
# weighted avg       0.89      0.81      0.84        86
#
# --- Evaluation Metrics ---
# Accuracy          : 0.8140
# Balanced Accuracy : 0.6815
# Macro Precision   : 0.6012
# Macro Recall      : 0.6815
# Macro F1          : 0.6167
#
# Confusion Matrix:
# [[ 1  0  2]
#  [ 5 50  7]
#  [ 2  0 19]]
#
# --- Fold 5/10 ---
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0
# Epoch 4/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.6618 - loss: 0.4000
# Epoch 4: val_loss improved from 0.34673 to 0.33681, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_7_frozen.keras
#
# Epoch 4: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_7_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - accuracy: 0.6761 - loss: 0.3935 - val_accuracy: 0.6860 - val_loss: 0.3368
# Epoch 5/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.6538 - loss: 0.4020
# Epoch 5: val_loss did not improve from 0.33681
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.6632 - loss: 0.4106 - val_accuracy: 0.6744 - val_loss: 0.4011
# Epoch 6/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.7018 - loss: 0.3453
# Epoch 6: val_loss did not improve from 0.33681
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 20s 414ms/step - accuracy: 0.7044 - loss: 0.3579 - val_accuracy: 0.7442 - val_loss: 0.3418
# Epoch 7/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6654 - loss: 0.3745
# Epoch 7: val_loss did not improve from 0.33681
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - accuracy: 0.6594 - loss: 0.3949 - val_accuracy: 0.7093 - val_loss: 0.3539
# Epoch 8/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.7087 - loss: 0.3240
# ...
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.7423 - loss: 0.2813 - val_accuracy: 0.7614 - val_loss: 0.3542
# Epoch 23/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.7431 - loss: 0.2793
# Epoch 23: val_loss improved from 0.35425 to 0.34453, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_8_frozen.keras
#
# Epoch 23: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_8_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 361ms/step - accuracy: 0.7397 - loss: 0.2790 - val_accuracy: 0.7386 - val_loss: 0.3445
# Epoch 24/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6874 - loss: 0.3128
# Epoch 24: val_loss did not improve from 0.34453
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 332ms/step - accuracy: 0.7113 - loss: 0.2831 - val_accuracy: 0.7386 - val_loss: 0.3652
# Epoch 25/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7685 - loss: 0.2516
# Epoch 25: val_loss did not improve from 0.34453
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 348ms/step - accuracy: 0.7397 - loss: 0.2752 - val_accuracy: 0.7159 - val_loss: 0.3568
# Epoch 26/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7432 - loss: 0.2634
# Epoch 26: val_loss improved from 0.34453 to 0.34394, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_8_frozen.keras
#
# Epoch 26: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_8_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 379ms/step - accuracy: 0.7358 - loss: 0.2774 - val_accuracy: 0.7614 - val_loss: 0.3439
# Epoch 27/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.7238 - loss: 0.2577
# Epoch 27: val_loss did not improve from 0.34394
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 330ms/step - accuracy: 0.7500 - loss: 0.2632 - val_accuracy: 0.7273 - val_loss: 0.3449
# Epoch 28/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7466 - loss: 0.2789
# Epoch 28: val_loss did not improve from 0.34394
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 432ms/step - accuracy: 0.7358 - loss: 0.2657 - val_accuracy: 0.7386 - val_loss: 0.3865
# Epoch 29/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7612 - loss: 0.2498
# Epoch 29: val_loss did not improve from 0.34394
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.7539 - loss: 0.2604 - val_accuracy: 0.7273 - val_loss: 0.3672
# Epoch 30/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.7355 - loss: 0.2571
# Epoch 30: val_loss did not improve from 0.34394
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s 359ms/step - accuracy: 0.7474 - loss: 0.2534 - val_accuracy: 0.7841 - val_loss: 0.3737
# Restoring model weights from the end of the best epoch: 26.
#
# --- Running Inference ---
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.44      0.69      0.54        16
#       Myopia       0.98      0.83      0.90        53
#    Hyperopia       0.67      0.63      0.65        19
#
#     accuracy                           0.76        88
#    macro avg       0.69      0.72      0.69        88
# weighted avg       0.81      0.76      0.78        88
#
# --- Evaluation Metrics ---
# Accuracy          : 0.7614
# Balanced Accuracy : 0.7164
# Macro Precision   : 0.6948
# Macro Recall      : 0.7164
# Macro F1          : 0.6944
#
# Confusion Matrix:
# [[11  1  4]
#  [ 7 44  2]
#  [ 7  0 12]]
#
# --- Fold 9/10 ---
# Epoch 1/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.4206 - loss: 0.9133
# Epoch 1: val_loss improved from None to 0.31957, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_9_frozen.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_9_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 636ms/step - accuracy: 0.5103 - loss: 0.7217 - val_accuracy: 0.7024 - val_loss: 0.3196
# Epoch 2/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.6147 - loss: 0.4875
# Epoch 2: val_loss did not improve from 0.31957
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 17s
# Epoch 9/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7114 - loss: 0.3219
# Epoch 9: val_loss did not improve from 0.33271
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - accuracy: 0.7032 - loss: 0.3256 - val_accuracy: 0.6742 - val_loss: 0.3428
# Epoch 10/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.6597 - loss: 0.3770
# Epoch 10: val_loss did not improve from 0.33271
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.6929 - loss: 0.3357 - val_accuracy: 0.6742 - val_loss: 0.3459
# Epoch 11/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.6759 - loss: 0.3521
# Epoch 11: val_loss improved from 0.33271 to 0.32017, saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_10_frozen.keras
#
# Epoch 11: finished saving model to /kaggle/working/RefraScan/artifacts/age_ablation/resnet50_age_fold_10_frozen.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 394ms/step - accuracy: 0.6929 - loss: 0.3393 - val_accuracy: 0.6854 - val_loss: 0.3202
# Epoch 12/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7045 - loss: 0.3336
# Epoch 12: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 16s 338ms/step - accuracy: 0.7006 - loss: 0.3164 - val_accuracy: 0.7079 - val_loss: 0.3390
# Epoch 13/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7236 - loss: 0.3040
# Epoch 13: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.7071 - loss: 0.3117 - val_accuracy: 0.7079 - val_loss: 0.3333
# Epoch 14/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7101 - loss: 0.3423
# Epoch 14: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 377ms/step - accuracy: 0.7084 - loss: 0.3205 - val_accuracy: 0.6742 - val_loss: 0.3333
# Epoch 15/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7311 - loss: 0.3022
# Epoch 15: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 377ms/step - accuracy: 0.7265 - loss: 0.2980 - val_accuracy: 0.6517 - val_loss: 0.3473
# Epoch 16/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.6929 - loss: 0.3359
# Epoch 16: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - accuracy: 0.7123 - loss: 0.3207 - val_accuracy: 0.6517 - val_loss: 0.3438
# Epoch 17/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7326 - loss: 0.2984
# Epoch 17: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 18s 379ms/step - accuracy: 0.7419 - loss: 0.2990 - val_accuracy: 0.6629 - val_loss: 0.3405
# Epoch 18/30
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.7158 - loss: 0.2886
# Epoch 18: val_loss did not improve from 0.32017
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 19s 390ms/step - accuracy: 0.7174 - loss: 0.2985 - val_accuracy: 0.6854 - val_loss: 0.3266
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 11.
#
# --- Running Inference ---
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.35      0.89      0.50         9
#       Myopia       0.92      0.76      0.83        63
#    Hyperopia       0.36      0.29      0.32        17
#
#     accuracy                           0.69        89
#    macro avg       0.54      0.65      0.55        89
# weighted avg       0.76      0.69      0.70        89
#
# --- Evaluation Metrics ---
# Accuracy          : 0.6854
# Balanced Accuracy : 0.6483
# Macro Precision   : 0.5427
# Macro Recall      : 0.6483
# Macro F1          : 0.5525
#
# Confusion Matrix:
# [[ 8  0  1]
#  [ 7 48  8]
#  [ 8  4  5]]
#
# ======================================================================
# RESNET50 | IMAGE + AGE CV SUMMARY
# ======================================================================
#  Fold    Model  Accuracy  Balanced Accuracy  Macro Precision  Macro Recall  Macro F1  Emmetropia Precision  Emmetropia Recall  Emmetropia F1  Myopia Precision  Myopia Recall  Myopia F1  Hyperopia Precision  Hyperopia Recall  Hyperopia F1
#     1 resnet50  0.717647           0.582418         0.568122      0.582418  0.573210              0.222222           0.285714       0.250000          0.875000       0.807692   0.840000             0.607143          0.653846      0.629630
#     2 resnet50  0.717647           0.555342         0.525617      0.555342  0.524700              0.100000           0.250000       0.142857          0.958333       0.779661   0.859813             0.518519          0.636364      0.571429
#     3 resnet50  0.770115           0.715045         0.667255      0.715045  0.681724              0.411765           0.636364       0.500000          0.940000       0.824561   0.878505             0.650000          0.684211      0.666667
#     4 resnet50  0.813953           0.681516         0.601190      0.681516  0.616729              0.125000           0.333333       0.181818          1.000000       0.806452   0.892857             0.678571          0.904762      0.775510
#     5 resnet50  0.781609           0.705687         0.663420      0.705687  0.673383              0.454545           0.500000       0.476190          1.000000       0.827586   0.905660             0.535714          0.789474      0.638298
#     6 resnet50  0.804598           0.700419         0.678752      0.700419  0.687025              0.363636           0.400000       0.380952          0.958333       0.867925   0.910891             0.714286          0.833333      0.769231
#     7 resnet50  0.709302           0.621511         0.562302      0.621511  0.563118              0.428571           0.857143       0.571429          0.958333       0.793103   0.867925             0.300000          0.214286      0.250000
#     8 resnet50  0.761364           0.716423         0.694815      0.716423  0.694398              0.440000           0.687500       0.536585          0.977778       0.830189   0.897959             0.666667          0.631579      0.648649
#     9 resnet50  0.702381           0.611643         0.578188      0.611643  0.577878              0.285714           0.545455       0.375000          0.978261       0.789474   0.873786             0.470588          0.500000      0.484848
#    10 resnet50  0.685393           0.648304         0.542682      0.648304  0.552454              0.347826           0.888889       0.500000          0.923077       0.761905   0.834783             0.357143          0.294118      0.322581
# Macro F1            : 0.6145 ± 0.0610
# Balanced Accuracy   : 0.6538 ± 0.0556
# Macro Precision     : 0.6082 ± 0.0590
# Macro Recall        : 0.6538 ± 0.0556
# Accuracy            : 0.7464 ± 0.0432
#
# Compare the Macro F1 and balanced accuracy means above before choosing the final configuration.

# %%
# ============================================================
# VISUALIZATION: IMAGE ONLY VS IMAGE + AGE
# ============================================================

import matplotlib.pyplot as plt
import numpy as np

# Get the actual fold-level results from the CV experiments
image_only_df = fine_tuned_results["fold_results"]
image_age_df = age_results["fold_results"]

# Metrics to visualize
metrics = [
    "Accuracy",
    "Balanced Accuracy",
    "Macro F1"
]

# Calculate the mean across the actual CV folds
image_only_values = [
    image_only_df["Accuracy"].mean(),
    image_only_df["Balanced Accuracy"].mean(),
    image_only_df["Macro F1"].mean()
]

image_age_values = [
    image_age_df["Accuracy"].mean(),
    image_age_df["Balanced Accuracy"].mean(),
    image_age_df["Macro F1"].mean()
]

# Display the actual values used in the graph
print("=== IMAGE ONLY VS IMAGE + AGE ===")
for metric, image_only, image_age in zip(
    metrics,
    image_only_values,
    image_age_values
):
    print(
        f"{metric}: "
        f"Image Only = {image_only:.4f}, "
        f"Image + Age = {image_age:.4f}"
    )

# ============================================================
# CREATE BAR CHART
# ============================================================

x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(9, 6))

ax.bar(
    x - width / 2,
    image_only_values,
    width,
    label="Image Only"
)

ax.bar(
    x + width / 2,
    image_age_values,
    width,
    label="Image + Age"
)

ax.set_title("ResNet50 Image-Only vs Image + Age Performance")
ax.set_ylabel("Score")
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.set_ylim(0, 1)
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# === IMAGE ONLY VS IMAGE + AGE ===
# Accuracy: Image Only = 0.7432, Image + Age = 0.7464
# Balanced Accuracy: Image Only = 0.6523, Image + Age = 0.6538
# Macro F1: Image Only = 0.6077, Image + Age = 0.6145

# %%
# -----------------------------------------------------------------------------
# FINAL TRAINING ON ALL 85% DEVELOPMENT DATA
# -----------------------------------------------------------------------------
# At this point the architecture and feature configuration have already been
# selected using development-data CV. The 15% holdout remains untouched.

USE_AGE = True  # Set True only if the image+age ablation is the selected final configuration.
METADATA_COLS = ["age_scaled"] if USE_AGE else None

# Epoch 29/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.7578 - loss: 0.2623
# Epoch 29: saving model to /kaggle/working/RefraScan/artifacts/final_model.keras
#
# Epoch 29: finished saving model to /kaggle/working/RefraScan/artifacts/final_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 380ms/step - accuracy: 0.7500 - loss: 0.2745
# Epoch 30/30
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.7244 - loss: 0.2913
# Epoch 30: saving model to /kaggle/working/RefraScan/artifacts/final_model.keras
#
# Epoch 30: finished saving model to /kaggle/working/RefraScan/artifacts/final_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 371ms/step - accuracy: 0.7373 - loss: 0.2711
# Fine-tuning resnet50: unfroze the upper 10 non-BatchNorm backbone layers.
# Epoch 1/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7420 - loss: 0.2633
# Epoch 1: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 34s 377ms/step - accuracy: 0.7535 - loss: 0.2649
# Epoch 2/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7360 - loss: 0.2614
# Epoch 2: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 2: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 377ms/step - accuracy: 0.7535 - loss: 0.2422
# Epoch 3/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.7740 - loss: 0.2509
# Epoch 3: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 3: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 378ms/step - accuracy: 0.7697 - loss: 0.2526
# Epoch 4/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.7411 - loss: 0.2326
# Epoch 4: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 4: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.7593 - loss: 0.2335
# Epoch 5/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7753 - loss: 0.2388
# Epoch 5: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 5: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - accuracy: 0.7755 - loss: 0.2322
# Epoch 6/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.8246 - loss: 0.2069
# Epoch 6: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 6: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 377ms/step - accuracy: 0.8021 - loss: 0.2191
# Epoch 7/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.7912 - loss: 0.2252
# Epoch 7: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 7: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 19s 361ms/step - accuracy: 0.7986 - loss: 0.2266
# Epoch 8/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8152 - loss: 0.2167
# Epoch 8: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 8: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 369ms/step - accuracy: 0.8125 - loss: 0.2115
# Epoch 9/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8044 - loss: 0.2183
# Epoch 9: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 9: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 369ms/step - accuracy: 0.8044 - loss: 0.2126
# Epoch 10/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8016 - loss: 0.2015
# Epoch 10: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
#
# Epoch 10: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_1.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 367ms/step - accuracy: 0.7998 - loss: 0.1976
# Fine-tuning resnet50: unfroze the upper 30 non-BatchNorm backbone layers.
# Epoch 1/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7908 - loss: 0.2226
# Epoch 1: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 1: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 37s 381ms/step - accuracy: 0.8009 - loss: 0.2131
# Epoch 2/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7763 - loss: 0.2179
# Epoch 2: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 2: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 21s 387ms/step - accuracy: 0.7870 - loss: 0.2164
# Epoch 3/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.8138 - loss: 0.2018
# Epoch 3: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 3: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 372ms/step - accuracy: 0.7998 - loss: 0.2112
# Epoch 4/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.8317 - loss: 0.2013
# Epoch 4: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 4: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - accuracy: 0.8310 - loss: 0.1866
# Epoch 5/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8257 - loss: 0.2034
# Epoch 5: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 5: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8252 - loss: 0.1990
# Epoch 6/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8462 - loss: 0.1748
# Epoch 6: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 6: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 26s 491ms/step - accuracy: 0.8229 - loss: 0.1864
# Epoch 7/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8221 - loss: 0.1882
# Epoch 7: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 7: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 29s 550ms/step - accuracy: 0.8345 - loss: 0.1768
# Epoch 8/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8548 - loss: 0.1647
# Epoch 8: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 8: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 371ms/step - accuracy: 0.8600 - loss: 0.1588
# Epoch 9/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8480 - loss: 0.1738
# Epoch 9: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 9: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 370ms/step - accuracy: 0.8611 - loss: 0.1707
# Epoch 10/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8378 - loss: 0.1596
# Epoch 10: saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
#
# Epoch 10: finished saving model to /kaggle/working/RefraScan/artifacts/final_model_finetune_stage_2.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 20s 367ms/step - accuracy: 0.8310 - loss: 0.1706
# Final model trained using development data only.

# %%
# ============================================================
# VISUALIZATION: FINAL MODEL TRAINING LOSS
# ============================================================

import matplotlib.pyplot as plt

history = final_history.history

plt.figure(figsize=(9, 6))

plt.plot(
    history["loss"],
    label="Training Loss"
)

plt.title("Final ResNet50 Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ============================================================
# VISUALIZATION: FINAL MODEL TRAINING ACCURACY
# ============================================================

import matplotlib.pyplot as plt

history = final_history.history

plt.figure(figsize=(9, 6))

plt.plot(
    history["accuracy"],
    label="Training Accuracy"
)

plt.title("Final ResNet50 Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# =============================================================================
# SIMPLE PAPILA vs AUF-MC GRAD-CAM EVALUATION
# =============================================================================

import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image

# -----------------------------------------------------------------------------
# 1. USE THE FINAL TRAINED RESNET50
# -----------------------------------------------------------------------------
model = final_model

# -----------------------------------------------------------------------------
# 2. USE THE HOLDOUT SET
# -----------------------------------------------------------------------------
gradcam_df = holdout_df.copy()

# Safety check: make sure age_scaled exists if USE_AGE is on, even if
# cell 8 (holdout evaluation) wasn't run first in this kernel session.
if USE_AGE and "age_scaled" not in gradcam_df.columns:
    import joblib
    age_scaler = joblib.load(
        f"/kaggle/working/{REPO_NAME}/artifacts/final_model_age_scaler.joblib"
    )
    gradcam_df["age_scaled"] = age_scaler.transform(gradcam_df[["age"]])

# -----------------------------------------------------------------------------
# 3. IMAGE SOURCE
# -----------------------------------------------------------------------------
gradcam_df["image_source"] = (
    gradcam_df["data_origin"]
    .astype(str)
    .str.strip()
    .str.upper()
)

# Normalize source names
gradcam_df["image_source"] = gradcam_df["image_source"].apply(
    lambda x:
        "PAPILA" if "PAPILA" in x
        else "AUF-MC" if "AUF" in x
        else "UNKNOWN"
)

# -----------------------------------------------------------------------------
# 4. CLASS LABELS
# -----------------------------------------------------------------------------
CLASS_NAMES = {
    0: "Emmetropia",
    1: "Myopia",
    2: "Hyperopia"
}

def get_label(value):

    if isinstance(value, (int, np.integer)):
        return int(value)

    value = str(value).strip().lower()

    mapping = {
        "emmetropia": 0,
        "myopia": 1,
        "hyperopia": 2,
        "0": 0,
        "1": 1,
        "2": 2
    }

    return mapping[value]


gradcam_df["true_label"] = (
    gradcam_df["classification"].apply(get_label)
)

# -----------------------------------------------------------------------------
# 5. FIND IMAGE PATH
# -----------------------------------------------------------------------------

if "full_path" in gradcam_df.columns:
    image_column = "full_path"

elif "image_path" in gradcam_df.columns:
    image_column = "image_path"

else:
    raise ValueError(
        "Could not find the image path column."
    )

# -----------------------------------------------------------------------------
# 6. IMAGE PREPROCESSING
# -----------------------------------------------------------------------------
IMAGE_SIZE = (224, 224)

def prepare_image(path):

    img = Image.open(path).convert("RGB")

    original = np.array(img)

    resized = img.resize(IMAGE_SIZE)

    array = np.array(resized).astype(np.float32)

    array = tf.keras.applications.resnet50.preprocess_input(
        array
    )

    return original, array

# -----------------------------------------------------------------------------
# 7. FIND LAST CONVOLUTIONAL LAYER
# -----------------------------------------------------------------------------
def find_last_conv_layer(model):

    for layer in reversed(model.layers):

        try:
            if len(layer.output.shape) == 4:
                return layer.name

        except:
            pass

    raise ValueError(
        "Could not find convolutional layer."
    )


LAST_CONV_LAYER_NAME = find_last_conv_layer(model)

print(
    "Grad-CAM layer:",
    LAST_CONV_LAYER_NAME
)

# -----------------------------------------------------------------------------
# 8. PREDICT ALL HOLDOUT IMAGES
# -----------------------------------------------------------------------------
predictions = []

for _, row in gradcam_df.iterrows():

    path = row[image_column]

    _, image_array = prepare_image(path)

    image_batch = np.expand_dims(image_array, axis=0)

    if USE_AGE:
        age_batch = np.array([[row["age_scaled"]]], dtype=np.float32)
        model_input = [image_batch, age_batch]
    else:
        model_input = image_batch

    prediction = model.predict(
        model_input,
        verbose=0
    )[0]

    predictions.append(
        np.argmax(prediction)
    )


gradcam_df["predicted_label"] = predictions

gradcam_df["prediction_status"] = np.where(
    gradcam_df["true_label"]
    ==
    gradcam_df["predicted_label"],
    "Correct",
    "Incorrect"
)

# =============================================================================
# 9. SIMPLE PAPILA vs AUF-MC RESULTS
# =============================================================================
print("\n")
print("=" * 60)
print("PAPILA vs AUF-MC PREDICTION RESULTS")
print("=" * 60)

source_results = (
    gradcam_df[
        gradcam_df["image_source"].isin(
            ["PAPILA", "AUF-MC"]
        )
    ]
    .groupby(
        ["image_source", "prediction_status"]
    )
    .size()
    .unstack(
        fill_value=0
    )
)

print(source_results)

# -----------------------------------------------------------------------------
# 10. PERCENTAGE OF CORRECT PREDICTIONS
# -----------------------------------------------------------------------------

for source in ["PAPILA", "AUF-MC"]:

    subset = gradcam_df[
        gradcam_df["image_source"] == source
    ]

    correct = (
        subset["prediction_status"] == "Correct"
    ).sum()

    total = len(subset)

    accuracy = (
        correct / total * 100
        if total > 0 else 0
    )

    print(
        f"{source}: "
        f"{correct}/{total} correct "
        f"({accuracy:.2f}%)"
    )

# =============================================================================
# 11. GRAD-CAM FUNCTION
# =============================================================================

def make_gradcam(
    image_array,
    model,
    layer_name,
    class_index,
    age_value=None
):

    grad_model = tf.keras.models.Model(
        model.inputs,
        [
            model.get_layer(layer_name).output,
            model.output
        ]
    )

    image_tensor = tf.expand_dims(
        image_array,
        axis=0
    )

    if age_value is not None:
        age_tensor = tf.constant(
            [[age_value]], dtype=tf.float32
        )
        model_input = [image_tensor, age_tensor]
    else:
        model_input = image_tensor

    with tf.GradientTape() as tape:

        conv_outputs, predictions = grad_model(
            model_input
        )

        class_output = predictions[:, class_index]

    gradients = tape.gradient(
        class_output,
        conv_outputs
    )

    pooled_gradients = tf.reduce_mean(
        gradients,
        axis=(0, 1, 2)
    )

    conv_outputs = conv_outputs[0]

    heatmap = (
        conv_outputs
        @ pooled_gradients[..., tf.newaxis]
    )

    heatmap = tf.squeeze(
        heatmap
    )

    heatmap = tf.maximum(
        heatmap,
        0
    )

    max_value = tf.reduce_max(
        heatmap
    )

    if max_value > 0:
        heatmap /= max_value

    return heatmap.numpy()

# =============================================================================
# 12. SELECT REPRESENTATIVE IMAGES
# =============================================================================
selected = []

for source in ["PAPILA", "AUF-MC"]:

    for status in ["Correct", "Incorrect"]:

        candidates = gradcam_df[
            (gradcam_df["image_source"] == source)
            &
            (gradcam_df["prediction_status"] == status)
        ]

        if len(candidates) > 0:

            selected.append(
                candidates.sample(
                    n=1,
                    random_state=42
                ).iloc[0]
            )

# =============================================================================
# 13. DISPLAY GRAD-CAM RESULTS
# =============================================================================
print("\n")
print("=" * 60)
print("GRAD-CAM EXAMPLES")
print("=" * 60)

for row in selected:

    path = row[image_column]
    original, image_array = prepare_image(
        path
    )

    predicted_class = int(
        row["predicted_label"]
    )

# Generate Grad-CAM
    heatmap = make_gradcam(
        image_array,
        model,
        LAST_CONV_LAYER_NAME,
        predicted_class,
        age_value=row["age_scaled"] if USE_AGE else None
    )

# Resize heatmap to original image dimensions
    heatmap_image = Image.fromarray(
        np.uint8(255 * heatmap)
    ).resize(
        (original.shape[1], original.shape[0])
    )

    heatmap_array = np.array(
        heatmap_image
    )

# -------------------------------------------------------------------------
# DISPLAY: ORIGINAL | GRAD-CAM | OVERLAY
# -------------------------------------------------------------------------

    fig, axes = plt.subplots(
        1,
        3,
        figsize=(15, 5)
    )

# 1. ORIGINAL IMAGE

    axes[0].imshow(original)

    axes[0].set_title(
        f"{row['image_source']} — Original\n"
        f"True: {CLASS_NAMES[row['true_label']]}"
    )

    axes[0].axis("off")

# 2. GRAD-CAM HEATMAP

    axes[1].imshow(
        heatmap_array,
        cmap="jet"
    )

    axes[1].set_title(
        f"Grad-CAM\n"
        f"Predicted: {CLASS_NAMES[predicted_class]}"
    )

    axes[1].axis("off")

 # 3. GRAD-CAM OVERLAY

    axes[2].imshow(original)

    axes[2].imshow(
        heatmap_array,
        cmap="jet",
        alpha=0.45
    )

    axes[2].set_title(
        f"Grad-CAM Overlay\n"
        f"{row['prediction_status']}"
    )

    axes[2].axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# Grad-CAM layer: conv5_block3_out
#
#
# ============================================================
# PAPILA vs AUF-MC PREDICTION RESULTS
# ============================================================
# prediction_status  Correct  Incorrect
# image_source
# AUF-MC                  67          9
# PAPILA                  38         40
# PAPILA: 38/78 correct (48.72%)
# AUF-MC: 67/76 correct (88.16%)
#
#
# ============================================================
# GRAD-CAM EXAMPLES
# ============================================================

# %%
# -----------------------------------------------------------------------------
# FINAL HOLDOUT EVALUATION -- RUN THIS CELL ONCE
# -----------------------------------------------------------------------------
# Do NOT rerun this evaluation to make additional architecture/hyperparameter
# decisions. The holdout is the final unbiased estimate.
if USE_AGE:
    import joblib
    age_scaler = joblib.load(
        f"/kaggle/working/{REPO_NAME}/artifacts/final_model_age_scaler.joblib"
    )
    holdout_df["age_scaled"] = age_scaler.transform(holdout_df[["age"]])

final_holdout_result = evaluate_holdout_once(
    model=final_model,
    holdout_df=holdout_df,
    preprocess_input=PREPROCESS_INPUT,
    batch_size=16,
    use_metadata=USE_AGE,
    metadata_cols=METADATA_COLS,
    model_name=BEST_MODEL_NAME,
)
# Out:
# --- Running Inference ---
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.42      0.37      0.39        27
#       Myopia       0.86      0.77      0.81        88
#    Hyperopia       0.59      0.77      0.67        39
#
#     accuracy                           0.70       154
#    macro avg       0.62      0.64      0.62       154
# weighted avg       0.71      0.70      0.70       154
#
# --- Evaluation Metrics ---
# Accuracy          : 0.7013
# Balanced Accuracy : 0.6374
# Macro Precision   : 0.6219
# Macro Recall      : 0.6374
# Macro F1          : 0.6244
#
# Confusion Matrix:
# [[10  5 12]
#  [11 68  9]
#  [ 3  6 30]]
#
# *** FINAL HOLDOUT EVALUATION COMPLETED ONCE ***

# %%
# ============================================================
# FINAL HOLDOUT PREDICTIONS FOR VISUALIZATION ONLY
# ============================================================

import numpy as np
import tensorflow as tf

# Use the SAME final model and untouched holdout dataframe.
# This is inference only for creating the visualization.

def make_holdout_dataset_for_visualization(
    dataframe,
    image_size,
    preprocess_input,
    use_metadata,
    metadata_cols
):
    image_paths = dataframe["full_path"].values
    labels = dataframe["classification_encoded"].values

    images = []

    for path in image_paths:
        image = tf.keras.utils.load_img(
            path,
            target_size=image_size
        )
        image = tf.keras.utils.img_to_array(image)
        image = preprocess_input(image)
        images.append(image)

    images = np.asarray(images, dtype=np.float32)

    if use_metadata:
        metadata = dataframe[metadata_cols].values.astype(np.float32)
        return (images, metadata), labels

    return images, labels


# ResNet50 uses 224 x 224 according to the final configuration
holdout_inputs, y_true = make_holdout_dataset_for_visualization(
    holdout_df,
    image_size=(224, 224),
    preprocess_input=PREPROCESS_INPUT,
    use_metadata=USE_AGE,
    metadata_cols=METADATA_COLS
)

# Generate predictions using the CURRENT final model
y_prob = final_model.predict(
    holdout_inputs,
    batch_size=16,
    verbose=1
)

y_pred = np.argmax(y_prob, axis=1)

print("Holdout samples:", len(y_true))
print("Predictions:", len(y_pred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step
# Holdout samples: 154
# Predictions: 154

# %%
# ============================================================
# VISUALIZATION: FINAL HOLDOUT CONFUSION MATRIX
# ============================================================

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

class_names = ["Emmetropia", "Myopia", "Hyperopia"]

cm = confusion_matrix(
    y_true,
    y_pred,
    labels=np.arange(len(class_names))
)

fig, ax = plt.subplots(figsize=(7, 6))

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names
)

disp.plot(
    ax=ax,
    values_format="d",
    colorbar=False
)

ax.set_title("Final Holdout Test Confusion Matrix")
ax.set_xlabel("Predicted Class")
ax.set_ylabel("Actual Class")

plt.tight_layout()
plt.show()

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[ 2 10 15]
#  [ 3 70 15]
#  [ 0  9 30]]

# %%
# ============================================================
# VISUALIZATION: FINAL HOLDOUT PER-CLASS PERFORMANCE
# ============================================================

from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, support = precision_recall_fscore_support(
    y_true,
    y_pred,
    labels=np.arange(len(class_names)),
    zero_division=0
)

x = np.arange(len(class_names))
width = 0.25

fig, ax = plt.subplots(figsize=(9, 6))

ax.bar(
    x - width,
    precision,
    width,
    label="Precision"
)

ax.bar(
    x,
    recall,
    width,
    label="Recall"
)

ax.bar(
    x + width,
    f1,
    width,
    label="F1-Score"
)

ax.set_title("Final Holdout Per-Class Performance")
ax.set_ylabel("Score")
ax.set_xlabel("Refractive Error Class")

ax.set_xticks(x)
ax.set_xticklabels(class_names)
ax.set_ylim(0, 1)

ax.legend()

plt.tight_layout()
plt.show()

# Also print the values for your Chapter 4 table
for i, class_name in enumerate(class_names):
    print(
        f"{class_name}: "
        f"Precision={precision[i]:.4f}, "
        f"Recall={recall[i]:.4f}, "
        f"F1={f1[i]:.4f}, "
        f"Support={support[i]}"
    )
# Out:
# Emmetropia: Precision=0.4000, Recall=0.0741, F1=0.1250, Support=27
# Myopia: Precision=0.7865, Recall=0.7955, F1=0.7910, Support=88
# Hyperopia: Precision=0.5000, Recall=0.7692, F1=0.6061, Support=39

# %%
# ============================================================
# VISUALIZATION: DEVELOPMENT/CV VS FINAL HOLDOUT
# ============================================================

import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    balanced_accuracy_score
)

# ------------------------------------------------------------
# 1. GET ACTUAL DEVELOPMENT/CV RESULTS
# ------------------------------------------------------------
# The Image + Age experiment stores its fold-level results
# in age_results["fold_results"], not age_results["summary"].

dev_results = age_results["fold_results"]

# Calculate the mean across the actual 10 CV folds
development_values = [
    dev_results["Accuracy"].mean(),
    dev_results["Macro Precision"].mean(),
    dev_results["Macro Recall"].mean(),
    dev_results["Macro F1"].mean(),
    dev_results["Balanced Accuracy"].mean()
]

# ------------------------------------------------------------
# 2. CALCULATE ACTUAL FINAL HOLDOUT RESULTS
# ------------------------------------------------------------
# y_true and y_pred must come from the final untouched
# 15% holdout evaluation.

holdout_values = [
    accuracy_score(y_true, y_pred),

    precision_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0
    ),

    recall_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0
    ),

    f1_score(
        y_true,
        y_pred,
        average="macro",
        zero_division=0
    ),

    balanced_accuracy_score(
        y_true,
        y_pred
    )
]

# ------------------------------------------------------------
# 3. DISPLAY THE ACTUAL VALUES
# ------------------------------------------------------------

metrics = [
    "Accuracy",
    "Macro Precision",
    "Macro Recall",
    "Macro F1",
    "Balanced Accuracy"
]

print("=" * 70)
print("DEVELOPMENT/CV VS FINAL HOLDOUT")
print("=" * 70)

for metric, dev, holdout in zip(
    metrics,
    development_values,
    holdout_values
):
    print(
        f"{metric:<20} "
        f"Development/CV: {dev:.4f} | "
        f"Final Holdout: {holdout:.4f}"
    )

# ------------------------------------------------------------
# 4. CREATE BAR CHART
# ------------------------------------------------------------

x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(
    x - width / 2,
    development_values,
    width,
    label="Development CV (Mean)"
)

ax.bar(
    x + width / 2,
    holdout_values,
    width,
    label="Final Holdout Test"
)

ax.set_title("Development Cross-Validation vs Final Holdout Test Performance")
ax.set_ylabel("Score")
ax.set_xticks(x)
ax.set_xticklabels(metrics, rotation=20)
ax.set_ylim(0, 1)

ax.legend()

plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# DEVELOPMENT/CV VS FINAL HOLDOUT
# ======================================================================
# Accuracy             Development/CV: 0.7464 | Final Holdout: 0.6623
# Macro Precision      Development/CV: 0.6082 | Final Holdout: 0.5622
# Macro Recall         Development/CV: 0.6538 | Final Holdout: 0.5463
# Macro F1             Development/CV: 0.6145 | Final Holdout: 0.5073
# Balanced Accuracy    Development/CV: 0.6538 | Final Holdout: 0.5463

# %%
# -----------------------------------------------------------------------------
# DEPLOYMENT EXPORT
# -----------------------------------------------------------------------------
# Save the trained final model and, when age is part of the selected
# configuration, its fitted scaler using the filenames expected by the app.
# Existing .pkl/.h5 artifacts are intentionally preserved in the repository.

import os
import shutil

MODEL_DIR = os.path.join(REPO_PATH, "models")
os.makedirs(MODEL_DIR, exist_ok=True)

deployment_model_path = os.path.join(
    MODEL_DIR, f"best_{BEST_MODEL_NAME}_fold_1.keras"
)
shutil.copy2(
    f"/kaggle/working/{REPO_NAME}/artifacts/final_model.keras",
    deployment_model_path,
)

if USE_AGE:
    deployment_scaler_path = os.path.join(MODEL_DIR, "scaler_fold_1.joblib")
    shutil.copy2(
        f"/kaggle/working/{REPO_NAME}/artifacts/final_model_age_scaler.joblib",
        deployment_scaler_path,
    )
    print(f"Deployment scaler: {deployment_scaler_path}")

print(f"Deployment model: {deployment_model_path}")
print("Deployment export completed. Existing legacy .pkl/.h5 files were not removed.")
# Out:
# Deployment scaler: /kaggle/working/RefraScan/models/scaler_fold_1.joblib
# Deployment model: /kaggle/working/RefraScan/models/best_resnet50_fold_1.keras
# Deployment export completed. Existing legacy .pkl/.h5 files were not removed.
