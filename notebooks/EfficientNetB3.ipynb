# %%
import os
import logging

# 1. Force C++ backend to only show FATAL errors
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=0"

# 2. Silence Python's absl logging module before importing TensorFlow
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# 3. Silence Python's standard logging for TensorFlow
logging.getLogger('tensorflow').setLevel(logging.FATAL)

import tensorflow as tf

# %%
import sys

# --- CONFIGURATION ---
REPO_NAME = "RefraScan"
# Make sure your username and repo name are spelled EXACTLY as they appear on GitHub
GITHUB_USER = "KyziaPi" 
BRANCH_NAME = "preprocessing-optimization"  
# ---------------------

REPO_URL = f"https://github.com/{GITHUB_USER}/{REPO_NAME}.git"
REPO_PATH = os.path.join("/kaggle/working", REPO_NAME)

if not os.path.exists(REPO_NAME):
    print(f"Cloning branch '{BRANCH_NAME}' from {REPO_NAME}...")
    # env={"GIT_TERMINAL_PROMPT": "0"} tells Git to instantly fail instead of hanging if it can't find the repo
    # !env GIT_TERMINAL_PROMPT=0 git clone -b {BRANCH_NAME} {REPO_URL}
else:
    print(f"{REPO_NAME} already exists. Switching branch and pulling latest updates...")
    # !cd {REPO_NAME} && env GIT_TERMINAL_PROMPT=0 git fetch --all && git checkout {BRANCH_NAME} && git pull origin {BRANCH_NAME}

# Add the repository root to sys.path so Python can find the 'src' package
if os.path.exists(REPO_PATH):
    if REPO_PATH not in sys.path:
        sys.path.append(REPO_PATH)
    
    # Import your modular components
    import math
    import pandas as pd
    from tensorflow.keras.applications.efficientnet import preprocess_input

    try:
        from src.preprocessing import load_and_clean_data, calculate_class_weights, scale_age_feature, split_data_by_patient, create_multimodal_generator
        from src.models import build_efficientnet
        from src.train import train_model
        from src.evaluate import evaluate_model
        from src.cross_validation import run_cross_validation
        print("🚀 Success! Custom modules imported smoothly.")
    except ModuleNotFoundError as e:
        print(f"❌ Still failing. Current sys.path contains: {sys.path}")
        raise e

    print(f"Environment configured successfully! Working on branch: {BRANCH_NAME}")
else:
    print("❌ Error: Repository failed to clone. Double check your GITHUB_USER name and ensure the branch 'preprocessing_test' actually exists on GitHub.")
# Out:
# Cloning branch 'preprocessing-optimization' from RefraScan...
# Cloning into 'RefraScan'...
# remote: Enumerating objects: 245, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 245 (delta 10), reused 23 (delta 9), pack-reused 219 (from 1)
# Receiving objects: 100% (245/245), 50.18 KiB | 734.00 KiB/s, done.
# Resolving deltas: 100% (112/112), done.
# 🚀 Success! Custom modules imported smoothly.
# Environment configured successfully! Working on branch: preprocessing-optimization

# %%
# 1. Configure Paths
DATASET_DIR = '/kaggle/input/datasets/yerikaelainegueco/fundus-images-with-refractive-values' 
CSV_PATH = os.path.join(DATASET_DIR, 'RefraScan_dataset.csv')
IMG_DIR = os.path.join(DATASET_DIR, 'FundusImages')

# 2. Load and clean entire dataset
df = load_and_clean_data(CSV_PATH, IMG_DIR)

# 3. Map targets
df['classification_encoded'] = df['classification'].map(
    {'Emmetropia': 0, 'Myopia': 1, 'Hyperopia': 2}
)

# 4. Run Cross-Validation Pipeline
# (Splitting, Scaling, Training, and Evaluation are all handled internally per-fold)
results = run_cross_validation(
    df=df,
    model_name='efficientnet',
    preprocess_input = preprocess_input,
    patient_col="ID",
    target_col="classification_encoded",
    n_splits=10,
    batch_size=16,
    epochs=30,
    learning_rate=0.0001,
    holdout_test_size=0.15,
)
# Out:
# Dataset Split: 866 samples for 10-Fold CV | 152 samples in Holdout Test Set (15%)
#
# =================================================================
# STARTING 10-FOLD CROSS VALIDATION
# =================================================================
#
#
# --- Fold 1/10 ---
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784878514.317603      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1784878514.320402      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/30
# I0000 00:00:1784878565.623133     140 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.3852 - loss: 0.7003
# Epoch 1: val_loss improved from None to 0.33983, saving model to best_efficientnet_fold_1.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_1.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 103s 599ms/step - accuracy: 0.4368 - loss: 0.5957 - val_accuracy: 0.6354 - val_loss: 0.3398
# Epoch 2/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.5211 - loss: 0.5150
# Epoch 2: val_loss improved from 0.33983 to 0.32693, saving model to best_efficientnet_fold_1.h5
#
# Epoch 2: finished saving model to best_efficientnet_fold_1.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 42s 439ms/step - accuracy: 0.5234 - loss: 0.5095 - val_accuracy: 0.7500 - val_loss: 0.3269
# Epoch 3/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.5521 - loss: 0.4797
# Epoch 3: val_loss improved from 0.32693 to 0.30534, saving model to best_efficientnet_fold_1.h5
#
# Epoch 3: finished saving model to best_efficientnet_fold_1.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.5599 - loss: 0.4625 - val_accuracy: 0.7188 - val_loss: 0.3053
# Epoch 4/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.5866 - loss: 0.4455
# Epoch 4: val_loss did not improve from 0.30534
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 39s 407ms/step - accuracy: 0.5924 - loss: 0.4445 - val_accuracy: 0.6979 - val_loss: 0.3343
# Epoch 5/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.6095 - loss: 0.4260
# Epoch 5: val_loss improved from 0.30534 to 0.26135, saving model to best_efficientnet_fold_1.h5
#
# Epoch 5: finished saving model to best_efficientnet_fold_1.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 430ms/step - accuracy: 0.6152 - loss: 0.4153 - val_accuracy: 0.7708 - val_loss: 0.2614
# Epoch 6/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.6330 - loss: 0.3963
# Epoch 6: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6445 - loss: 0.3834 - val_accuracy: 0.7396 - val_loss: 0.2994
# Epoch 7/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6408 - loss: 0.3976
# Epoch 7: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.6289 - loss: 0.3996 - val_accuracy: 0.7604 - val_loss: 0.3016
# Epoch 8/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.6239 - loss: 0.3775
# Epoch 8: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 422ms/step - accuracy: 0.6406 - loss: 0.3750 - val_accuracy: 0.7500 - val_loss: 0.3185
# Epoch 9/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.6347 - loss: 0.3948
# Epoch 9: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.6478 - loss: 0.3820 - val_accuracy: 0.7917 - val_loss: 0.2778
# Epoch 10/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.6679 - loss: 0.3670
# Epoch 10: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 39s 407ms/step - accuracy: 0.6660 - loss: 0.3643 - val_accuracy: 0.7812 - val_loss: 0.2623
# Epoch 11/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.6655 - loss: 0.3715
# Epoch 11: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 39s 410ms/step - accuracy: 0.6738 - loss: 0.3605 - val_accuracy: 0.7708 - val_loss: 0.2930
# Epoch 12/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.6889 - loss: 0.3437
# Epoch 12: val_loss did not improve from 0.26135
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 38s 403ms/step - accuracy: 0.6810 - loss: 0.3403 - val_accuracy: 0.7500 - val_loss: 0.3006
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 5.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 266ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Emmetropia   | 0.1561       | 0.6957       | 0.1482
# Emmetropia   | 0.1603       | 0.6075       | 0.2322
# Hyperopia    | 0.4962       | 0.0965       | 0.4073
# Emmetropia   | 0.3679       | 0.1147       | 0.5174
# Hyperopia    | 0.1395       | 0.7022       | 0.1582
# Hyperopia    | 0.3661       | 0.1058       | 0.5280
# Hyperopia    | 0.1101       | 0.7252       | 0.1647
# Hyperopia    | 0.1271       | 0.6863       | 0.1867
# Myopia       | 0.4882       | 0.0859       | 0.4259
# Hyperopia    | 0.2067       | 0.5714       | 0.2219
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.1561       | 0.6957       | 0.1482
# Emmetropia   | 0.1603       | 0.6075       | 0.2322
# Emmetropia   | 0.3679       | 0.1147       | 0.5174 <-- CLOSE!
# Emmetropia   | 0.4428       | 0.0567       | 0.5005 <-- CLOSE!
# Emmetropia   | 0.2067       | 0.5714       | 0.2219 <-- CLOSE!
# Emmetropia   | 0.1561       | 0.6957       | 0.1482
# Emmetropia   | 0.1859       | 0.6024       | 0.2117
# Emmetropia   | 0.2642       | 0.4789       | 0.2569 <-- CLOSE!
# Emmetropia   | 0.4578       | 0.1156       | 0.4265 <-- CLOSE!
# Emmetropia   | 0.4096       | 0.1492       | 0.4411 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.06      0.09      0.07        11
#       Myopia       0.53      0.44      0.48        52
#    Hyperopia       0.20      0.22      0.21        23
#
#     accuracy                           0.34        86
#    macro avg       0.26      0.25      0.25        86
# weighted avg       0.38      0.34      0.36        86
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.3372 (33.72%)
# Precision (Weighted): 0.3840
# Recall (Weighted)   : 0.3372
# F1 Score (Weighted) : 0.3573
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 346ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.4749       | 0.1054       | 0.4197
# Hyperopia    | 0.1983       | 0.6159       | 0.1858
# Emmetropia   | 0.4078       | 0.0805       | 0.5117
# Myopia       | 0.2592       | 0.5516       | 0.1892
# Hyperopia    | 0.1150       | 0.7266       | 0.1583
# Myopia       | 0.4065       | 0.1007       | 0.4928
# Hyperopia    | 0.4352       | 0.0915       | 0.4733
# Emmetropia   | 0.1180       | 0.7301       | 0.1519
# Hyperopia    | 0.1193       | 0.7080       | 0.1726
# Emmetropia   | 0.1445       | 0.6059       | 0.2496
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.4078       | 0.0805       | 0.5117 <-- CLOSE!
# Emmetropia   | 0.1180       | 0.7301       | 0.1519
# Emmetropia   | 0.1445       | 0.6059       | 0.2496
# Emmetropia   | 0.1095       | 0.7570       | 0.1335
# Emmetropia   | 0.4602       | 0.1180       | 0.4218 <-- CLOSE!
# Emmetropia   | 0.4276       | 0.1221       | 0.4502 <-- CLOSE!
# Emmetropia   | 0.3930       | 0.1033       | 0.5038 <-- CLOSE!
# Emmetropia   | 0.2186       | 0.5334       | 0.2480 <-- CLOSE!
# Emmetropia   | 0.1320       | 0.7344       | 0.1336
# Emmetropia   | 0.4722       | 0.0819       | 0.4460 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.10      0.20      0.13        20
#       Myopia       0.59      0.48      0.53        97
#    Hyperopia       0.24      0.23      0.24        35
#
#     accuracy                           0.39       152
#    macro avg       0.31      0.30      0.30       152
# weighted avg       0.45      0.39      0.41       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.3882 (38.82%)
# Precision (Weighted): 0.4486
# Recall (Weighted)   : 0.3882
# F1 Score (Weighted) : 0.4126
#
# --- Fold 2/10 ---
# Epoch 1/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.4108 - loss: 0.6809
# Epoch 1: val_loss improved from None to 0.40512, saving model to best_efficientnet_fold_2.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 89s 566ms/step - accuracy: 0.4572 - loss: 0.5926 - val_accuracy: 0.5833 - val_loss: 0.4051
# Epoch 2/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.5036 - loss: 0.4992
# Epoch 2: val_loss improved from 0.40512 to 0.39631, saving model to best_efficientnet_fold_2.h5
#
# Epoch 2: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.5395 - loss: 0.4745 - val_accuracy: 0.6354 - val_loss: 0.3963
# Epoch 3/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.5881 - loss: 0.4560
# Epoch 3: val_loss improved from 0.39631 to 0.38178, saving model to best_efficientnet_fold_2.h5
#
# Epoch 3: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 438ms/step - accuracy: 0.5829 - loss: 0.4556 - val_accuracy: 0.5833 - val_loss: 0.3818
# Epoch 4/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.5795 - loss: 0.4431
# Epoch 4: val_loss improved from 0.38178 to 0.36218, saving model to best_efficientnet_fold_2.h5
#
# Epoch 4: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6053 - loss: 0.4232 - val_accuracy: 0.6042 - val_loss: 0.3622
# Epoch 5/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.6128 - loss: 0.4193
# Epoch 5: val_loss did not improve from 0.36218
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 424ms/step - accuracy: 0.6145 - loss: 0.4121 - val_accuracy: 0.5938 - val_loss: 0.4713
# Epoch 6/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.6537 - loss: 0.3817
# Epoch 6: val_loss did not improve from 0.36218
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.6500 - loss: 0.3836 - val_accuracy: 0.5208 - val_loss: 0.4035
# Epoch 7/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.6560 - loss: 0.3816
# Epoch 7: val_loss did not improve from 0.36218
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6572 - loss: 0.3796 - val_accuracy: 0.6042 - val_loss: 0.3683
# Epoch 8/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6580 - loss: 0.3744
# Epoch 8: val_loss did not improve from 0.36218
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.6579 - loss: 0.3670 - val_accuracy: 0.6979 - val_loss: 0.3723
# Epoch 9/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.6729 - loss: 0.3490
# Epoch 9: val_loss improved from 0.36218 to 0.32450, saving model to best_efficientnet_fold_2.h5
#
# Epoch 9: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 445ms/step - accuracy: 0.6671 - loss: 0.3605 - val_accuracy: 0.6771 - val_loss: 0.3245
# Epoch 10/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.6700 - loss: 0.3621
# Epoch 10: val_loss did not improve from 0.32450
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 421ms/step - accuracy: 0.6809 - loss: 0.3479 - val_accuracy: 0.6458 - val_loss: 0.3696
# Epoch 11/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.6695 - loss: 0.3456
# Epoch 11: val_loss did not improve from 0.32450
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.6796 - loss: 0.3441 - val_accuracy: 0.5833 - val_loss: 0.4369
# Epoch 12/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6949 - loss: 0.3468
# Epoch 12: val_loss improved from 0.32450 to 0.30249, saving model to best_efficientnet_fold_2.h5
#
# Epoch 12: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 438ms/step - accuracy: 0.6941 - loss: 0.3398 - val_accuracy: 0.7500 - val_loss: 0.3025
# Epoch 13/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.6829 - loss: 0.3312
# Epoch 13: val_loss did not improve from 0.30249
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.6770 - loss: 0.3373 - val_accuracy: 0.6354 - val_loss: 0.3552
# Epoch 14/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7087 - loss: 0.3240
# Epoch 14: val_loss did not improve from 0.30249
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.7020 - loss: 0.3231 - val_accuracy: 0.6771 - val_loss: 0.3107
# Epoch 15/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.6984 - loss: 0.3158
# Epoch 15: val_loss did not improve from 0.30249
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 428ms/step - accuracy: 0.7033 - loss: 0.3103 - val_accuracy: 0.6562 - val_loss: 0.3656
# Epoch 16/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.6934 - loss: 0.3334
# Epoch 16: val_loss did not improve from 0.30249
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 422ms/step - accuracy: 0.7013 - loss: 0.3217 - val_accuracy: 0.6875 - val_loss: 0.3072
# Epoch 17/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7152 - loss: 0.3061
# Epoch 17: val_loss did not improve from 0.30249
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 426ms/step - accuracy: 0.7039 - loss: 0.3123 - val_accuracy: 0.6771 - val_loss: 0.3346
# Epoch 18/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7220 - loss: 0.3063
# Epoch 18: val_loss improved from 0.30249 to 0.29416, saving model to best_efficientnet_fold_2.h5
#
# Epoch 18: finished saving model to best_efficientnet_fold_2.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.7204 - loss: 0.3073 - val_accuracy: 0.7083 - val_loss: 0.2942
# Epoch 19/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.7394 - loss: 0.2904
# Epoch 19: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 38s 407ms/step - accuracy: 0.7414 - loss: 0.2893 - val_accuracy: 0.7396 - val_loss: 0.2955
# Epoch 20/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7432 - loss: 0.2947
# Epoch 20: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.7257 - loss: 0.2994 - val_accuracy: 0.6771 - val_loss: 0.4002
# Epoch 21/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.7218 - loss: 0.2832
# Epoch 21: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 422ms/step - accuracy: 0.7447 - loss: 0.2790 - val_accuracy: 0.6354 - val_loss: 0.4002
# Epoch 22/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.7413 - loss: 0.2837
# Epoch 22: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 435ms/step - accuracy: 0.7474 - loss: 0.2894 - val_accuracy: 0.6979 - val_loss: 0.3752
# Epoch 23/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7746 - loss: 0.2607
# Epoch 23: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.7546 - loss: 0.2734 - val_accuracy: 0.7188 - val_loss: 0.3249
# Epoch 24/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.7537 - loss: 0.2698
# Epoch 24: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.7507 - loss: 0.2763 - val_accuracy: 0.7083 - val_loss: 0.3309
# Epoch 25/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.7894 - loss: 0.2427
# Epoch 25: val_loss did not improve from 0.29416
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 430ms/step - accuracy: 0.7763 - loss: 0.2510 - val_accuracy: 0.6042 - val_loss: 0.3900
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 18.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 252ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.0347       | 0.8948       | 0.0704
# Hyperopia    | 0.4313       | 0.1252       | 0.4435
# Emmetropia   | 0.0598       | 0.8706       | 0.0697
# Myopia       | 0.0482       | 0.8736       | 0.0781
# Myopia       | 0.0875       | 0.7114       | 0.2011
# Emmetropia   | 0.0184       | 0.8962       | 0.0854
# Myopia       | 0.3779       | 0.0899       | 0.5322
# Hyperopia    | 0.0668       | 0.5814       | 0.3518
# Myopia       | 0.0474       | 0.8813       | 0.0713
# Hyperopia    | 0.0341       | 0.8275       | 0.1384
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.0598       | 0.8706       | 0.0697
# Emmetropia   | 0.0184       | 0.8962       | 0.0854
# Emmetropia   | 0.4278       | 0.1760       | 0.3962 <-- CLOSE!
# Emmetropia   | 0.4438       | 0.2213       | 0.3349 <-- CLOSE!
# Emmetropia   | 0.0350       | 0.9300       | 0.0350
# Emmetropia   | 0.4196       | 0.1804       | 0.4000 <-- CLOSE!
# Emmetropia   | 0.4007       | 0.0981       | 0.5012 <-- CLOSE!
# Emmetropia   | 0.3451       | 0.0725       | 0.5824 <-- CLOSE!
# Emmetropia   | 0.2694       | 0.3435       | 0.3871 <-- CLOSE!
# Emmetropia   | 0.2869       | 0.2920       | 0.4210 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.38      0.30      0.33        10
#       Myopia       0.76      0.61      0.67        61
#    Hyperopia       0.23      0.41      0.29        17
#
#     accuracy                           0.53        88
#    macro avg       0.45      0.44      0.43        88
# weighted avg       0.61      0.53      0.56        88
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.5341 (53.41%)
# Precision (Weighted): 0.6097
# Recall (Weighted)   : 0.5341
# F1 Score (Weighted) : 0.5605
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.3019       | 0.0575       | 0.6406
# Hyperopia    | 0.4171       | 0.0342       | 0.5487
# Emmetropia   | 0.3508       | 0.0737       | 0.5755
# Myopia       | 0.0355       | 0.8865       | 0.0780
# Hyperopia    | 0.0613       | 0.8436       | 0.0952
# Myopia       | 0.3927       | 0.1370       | 0.4704
# Hyperopia    | 0.1125       | 0.4815       | 0.4059
# Emmetropia   | 0.0988       | 0.5977       | 0.3035
# Hyperopia    | 0.0506       | 0.8556       | 0.0939
# Emmetropia   | 0.0644       | 0.8394       | 0.0962
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.3508       | 0.0737       | 0.5755 <-- CLOSE!
# Emmetropia   | 0.0988       | 0.5977       | 0.3035
# Emmetropia   | 0.0644       | 0.8394       | 0.0962
# Emmetropia   | 0.4993       | 0.0537       | 0.4470 <-- CLOSE!
# Emmetropia   | 0.3159       | 0.1106       | 0.5735 <-- CLOSE!
# Emmetropia   | 0.0506       | 0.8556       | 0.0939
# Emmetropia   | 0.5144       | 0.0559       | 0.4297 <-- CLOSE!
# Emmetropia   | 0.3587       | 0.0386       | 0.6027 <-- CLOSE!
# Emmetropia   | 0.2417       | 0.4754       | 0.2830 <-- CLOSE!
# Emmetropia   | 0.0675       | 0.7382       | 0.1943
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.10      0.15      0.12        20
#       Myopia       0.62      0.52      0.56        97
#    Hyperopia       0.24      0.29      0.26        35
#
#     accuracy                           0.41       152
#    macro avg       0.32      0.32      0.31       152
# weighted avg       0.46      0.41      0.43       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4145 (41.45%)
# Precision (Weighted): 0.4624
# Recall (Weighted)   : 0.4145
# F1 Score (Weighted) : 0.4344
#
# --- Fold 3/10 ---
# Epoch 1/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.3858 - loss: 0.6142
# Epoch 1: val_loss improved from None to 0.43753, saving model to best_efficientnet_fold_3.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_3.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 90s 564ms/step - accuracy: 0.4355 - loss: 0.5627 - val_accuracy: 0.6250 - val_loss: 0.4375
# Epoch 2/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.5472 - loss: 0.4635
# Epoch 2: val_loss did not improve from 0.43753
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.5579 - loss: 0.4575 - val_accuracy: 0.5104 - val_loss: 0.5018
# Epoch 3/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.6002 - loss: 0.4399
# Epoch 3: val_loss improved from 0.43753 to 0.40919, saving model to best_efficientnet_fold_3.h5
#
# Epoch 3: finished saving model to best_efficientnet_fold_3.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 42s 443ms/step - accuracy: 0.5944 - loss: 0.4367 - val_accuracy: 0.6562 - val_loss: 0.4092
# Epoch 4/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.6258 - loss: 0.4042
# Epoch 4: val_loss did not improve from 0.40919
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 416ms/step - accuracy: 0.6081 - loss: 0.4167 - val_accuracy: 0.6042 - val_loss: 0.4512
# Epoch 5/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6136 - loss: 0.4040
# Epoch 5: val_loss did not improve from 0.40919
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.6165 - loss: 0.4012 - val_accuracy: 0.5625 - val_loss: 0.4202
# Epoch 6/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.6362 - loss: 0.4058
# Epoch 6: val_loss did not improve from 0.40919
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 426ms/step - accuracy: 0.6361 - loss: 0.3894 - val_accuracy: 0.5417 - val_loss: 0.4664
# Epoch 7/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.6036 - loss: 0.4036
# Epoch 7: val_loss did not improve from 0.40919
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 434ms/step - accuracy: 0.6152 - loss: 0.3944 - val_accuracy: 0.7083 - val_loss: 0.4547
# Epoch 8/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.6472 - loss: 0.3721
# Epoch 8: val_loss improved from 0.40919 to 0.31095, saving model to best_efficientnet_fold_3.h5
#
# Epoch 8: finished saving model to best_efficientnet_fold_3.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 42s 438ms/step - accuracy: 0.6712 - loss: 0.3541 - val_accuracy: 0.7500 - val_loss: 0.3110
# Epoch 9/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.6535 - loss: 0.3687
# Epoch 9: val_loss did not improve from 0.31095
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 417ms/step - accuracy: 0.6510 - loss: 0.3710 - val_accuracy: 0.7083 - val_loss: 0.3968
# Epoch 10/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6667 - loss: 0.3456
# Epoch 10: val_loss did not improve from 0.31095
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 430ms/step - accuracy: 0.6673 - loss: 0.3508 - val_accuracy: 0.6771 - val_loss: 0.3772
# Epoch 11/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6982 - loss: 0.3518
# Epoch 11: val_loss did not improve from 0.31095
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 432ms/step - accuracy: 0.6816 - loss: 0.3536 - val_accuracy: 0.6771 - val_loss: 0.4624
# Epoch 12/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6887 - loss: 0.3257
# Epoch 12: val_loss improved from 0.31095 to 0.28467, saving model to best_efficientnet_fold_3.h5
#
# Epoch 12: finished saving model to best_efficientnet_fold_3.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 42s 441ms/step - accuracy: 0.6777 - loss: 0.3331 - val_accuracy: 0.6979 - val_loss: 0.2847
# Epoch 13/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.7102 - loss: 0.3197
# Epoch 13: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 416ms/step - accuracy: 0.7070 - loss: 0.3190 - val_accuracy: 0.7188 - val_loss: 0.4163
# Epoch 14/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.7063 - loss: 0.3299
# Epoch 14: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 42s 438ms/step - accuracy: 0.6921 - loss: 0.3315 - val_accuracy: 0.6146 - val_loss: 0.3846
# Epoch 15/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7019 - loss: 0.3292
# Epoch 15: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 428ms/step - accuracy: 0.6855 - loss: 0.3348 - val_accuracy: 0.7188 - val_loss: 0.4712
# Epoch 16/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.6972 - loss: 0.3362
# Epoch 16: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 421ms/step - accuracy: 0.6986 - loss: 0.3188 - val_accuracy: 0.6979 - val_loss: 0.5537
# Epoch 17/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7264 - loss: 0.2972
# Epoch 17: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 39s 409ms/step - accuracy: 0.7096 - loss: 0.3093 - val_accuracy: 0.7188 - val_loss: 0.3341
# Epoch 18/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.6958 - loss: 0.3067
# Epoch 18: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 417ms/step - accuracy: 0.6999 - loss: 0.3129 - val_accuracy: 0.6771 - val_loss: 0.4921
# Epoch 19/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.7349 - loss: 0.2963
# Epoch 19: val_loss did not improve from 0.28467
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.7279 - loss: 0.2990 - val_accuracy: 0.6250 - val_loss: 0.3158
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 242ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Hyperopia    | 0.4189       | 0.0804       | 0.5008
# Emmetropia   | 0.4665       | 0.1051       | 0.4284
# Hyperopia    | 0.0564       | 0.8316       | 0.1120
# Hyperopia    | 0.4147       | 0.1395       | 0.4459
# Myopia       | 0.5490       | 0.0735       | 0.3775
# Hyperopia    | 0.4355       | 0.0969       | 0.4676
# Myopia       | 0.3686       | 0.1646       | 0.4668
# Hyperopia    | 0.4943       | 0.0927       | 0.4130
# Hyperopia    | 0.4011       | 0.1847       | 0.4142
# Emmetropia   | 0.0611       | 0.8299       | 0.1090
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.4665       | 0.1051       | 0.4284 <-- CLOSE!
# Emmetropia   | 0.0611       | 0.8299       | 0.1090
# Emmetropia   | 0.4859       | 0.1181       | 0.3960 <-- CLOSE!
# Emmetropia   | 0.0963       | 0.7930       | 0.1107
# Emmetropia   | 0.4161       | 0.1103       | 0.4736 <-- CLOSE!
# Emmetropia   | 0.0384       | 0.8860       | 0.0756
# Emmetropia   | 0.5489       | 0.0997       | 0.3514 <-- CLOSE!
# Emmetropia   | 0.0963       | 0.7930       | 0.1107
# Emmetropia   | 0.0500       | 0.9071       | 0.0429
# Emmetropia   | 0.0335       | 0.8610       | 0.1055
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.24      0.33      0.28        15
#       Myopia       0.65      0.55      0.60        56
#    Hyperopia       0.32      0.35      0.33        17
#
#     accuracy                           0.48        88
#    macro avg       0.40      0.41      0.40        88
# weighted avg       0.51      0.48      0.49        88
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4773 (47.73%)
# Precision (Weighted): 0.5126
# Recall (Weighted)   : 0.4773
# F1 Score (Weighted) : 0.4911
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.0292       | 0.9046       | 0.0662
# Hyperopia    | 0.4234       | 0.1268       | 0.4497
# Emmetropia   | 0.2916       | 0.5946       | 0.1138
# Myopia       | 0.0734       | 0.8772       | 0.0495
# Hyperopia    | 0.1136       | 0.7261       | 0.1603
# Myopia       | 0.4751       | 0.1503       | 0.3746
# Hyperopia    | 0.0398       | 0.8695       | 0.0907
# Emmetropia   | 0.5456       | 0.1142       | 0.3402
# Hyperopia    | 0.0411       | 0.8860       | 0.0729
# Emmetropia   | 0.0432       | 0.8550       | 0.1018
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.2916       | 0.5946       | 0.1138 <-- CLOSE!
# Emmetropia   | 0.5456       | 0.1142       | 0.3402 <-- CLOSE!
# Emmetropia   | 0.0432       | 0.8550       | 0.1018
# Emmetropia   | 0.0516       | 0.7820       | 0.1664
# Emmetropia   | 0.0292       | 0.9046       | 0.0662
# Emmetropia   | 0.0422       | 0.8590       | 0.0988
# Emmetropia   | 0.3906       | 0.1216       | 0.4878 <-- CLOSE!
# Emmetropia   | 0.3748       | 0.1763       | 0.4489 <-- CLOSE!
# Emmetropia   | 0.4199       | 0.1430       | 0.4371 <-- CLOSE!
# Emmetropia   | 0.4570       | 0.0942       | 0.4488 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.21      0.35      0.26        20
#       Myopia       0.68      0.55      0.61        97
#    Hyperopia       0.25      0.29      0.27        35
#
#     accuracy                           0.46       152
#    macro avg       0.38      0.39      0.38       152
# weighted avg       0.52      0.46      0.48       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4605 (46.05%)
# Precision (Weighted): 0.5183
# Recall (Weighted)   : 0.4605
# F1 Score (Weighted) : 0.4821
#
# --- Fold 4/10 ---
# Epoch 1/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.3743 - loss: 0.7942
# Epoch 1: val_loss improved from None to 0.36908, saving model to best_efficientnet_fold_4.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_4.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 87s 545ms/step - accuracy: 0.4160 - loss: 0.6479 - val_accuracy: 0.6875 - val_loss: 0.3691
# Epoch 2/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.5059 - loss: 0.5138
# Epoch 2: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.5280 - loss: 0.4975 - val_accuracy: 0.6354 - val_loss: 0.3925
# Epoch 3/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.5679 - loss: 0.4538
# Epoch 3: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 421ms/step - accuracy: 0.5885 - loss: 0.4451 - val_accuracy: 0.5625 - val_loss: 0.4362
# Epoch 4/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.5975 - loss: 0.4290
# Epoch 4: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 418ms/step - accuracy: 0.6048 - loss: 0.4272 - val_accuracy: 0.6042 - val_loss: 0.4172
# Epoch 5/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.6101 - loss: 0.4158
# Epoch 5: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 40s 423ms/step - accuracy: 0.6250 - loss: 0.4041 - val_accuracy: 0.6042 - val_loss: 0.4084
# Epoch 6/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.6454 - loss: 0.3878
# Epoch 6: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 42s 437ms/step - accuracy: 0.6621 - loss: 0.3808 - val_accuracy: 0.5729 - val_loss: 0.4677
# Epoch 7/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.6529 - loss: 0.3917
# Epoch 7: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.6556 - loss: 0.3859 - val_accuracy: 0.5417 - val_loss: 0.4601
# Epoch 8/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.6495 - loss: 0.3827
# Epoch 8: val_loss did not improve from 0.36908
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6510 - loss: 0.3701 - val_accuracy: 0.6042 - val_loss: 0.4324
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Emmetropia   | 0.2713       | 0.4200       | 0.3087
# Emmetropia   | 0.2926       | 0.3959       | 0.3116
# Myopia       | 0.4857       | 0.1227       | 0.3916
# Myopia       | 0.5518       | 0.0787       | 0.3695
# Hyperopia    | 0.2768       | 0.4368       | 0.2864
# Hyperopia    | 0.4772       | 0.1280       | 0.3948
# Emmetropia   | 0.3950       | 0.1835       | 0.4215
# Hyperopia    | 0.4510       | 0.1213       | 0.4277
# Hyperopia    | 0.2951       | 0.4411       | 0.2639
# Myopia       | 0.2993       | 0.4485       | 0.2522
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.2713       | 0.4200       | 0.3087 <-- CLOSE!
# Emmetropia   | 0.2926       | 0.3959       | 0.3116 <-- CLOSE!
# Emmetropia   | 0.3950       | 0.1835       | 0.4215 <-- CLOSE!
# Emmetropia   | 0.2897       | 0.3902       | 0.3201 <-- CLOSE!
# Emmetropia   | 0.5153       | 0.0927       | 0.3920 <-- CLOSE!
# Emmetropia   | 0.2270       | 0.4825       | 0.2905 <-- CLOSE!
# Emmetropia   | 0.2885       | 0.4332       | 0.2783 <-- CLOSE!
# Emmetropia   | 0.2886       | 0.4141       | 0.2973 <-- CLOSE!
# Emmetropia   | 0.2708       | 0.3899       | 0.3393 <-- CLOSE!
# Emmetropia   | 0.2950       | 0.4227       | 0.2824 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.08      0.15      0.11        13
#       Myopia       0.58      0.58      0.58        53
#    Hyperopia       0.33      0.11      0.17        18
#
#     accuracy                           0.42        84
#    macro avg       0.33      0.28      0.29        84
# weighted avg       0.45      0.42      0.42        84
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4167 (41.67%)
# Precision (Weighted): 0.4529
# Recall (Weighted)   : 0.4167
# F1 Score (Weighted) : 0.4211
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 320ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.2614       | 0.4626       | 0.2760
# Hyperopia    | 0.5076       | 0.0819       | 0.4105
# Emmetropia   | 0.4659       | 0.1067       | 0.4273
# Myopia       | 0.4962       | 0.0884       | 0.4154
# Hyperopia    | 0.5601       | 0.0813       | 0.3586
# Myopia       | 0.3154       | 0.3665       | 0.3182
# Hyperopia    | 0.4935       | 0.0857       | 0.4208
# Emmetropia   | 0.2686       | 0.4682       | 0.2632
# Hyperopia    | 0.2484       | 0.4599       | 0.2917
# Emmetropia   | 0.4823       | 0.1034       | 0.4143
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.4659       | 0.1067       | 0.4273 <-- CLOSE!
# Emmetropia   | 0.2686       | 0.4682       | 0.2632 <-- CLOSE!
# Emmetropia   | 0.4823       | 0.1034       | 0.4143 <-- CLOSE!
# Emmetropia   | 0.5517       | 0.1002       | 0.3481 <-- CLOSE!
# Emmetropia   | 0.4962       | 0.0884       | 0.4154 <-- CLOSE!
# Emmetropia   | 0.3516       | 0.1716       | 0.4768 <-- CLOSE!
# Emmetropia   | 0.4935       | 0.0857       | 0.4208 <-- CLOSE!
# Emmetropia   | 0.4159       | 0.1072       | 0.4769 <-- CLOSE!
# Emmetropia   | 0.5206       | 0.0873       | 0.3921 <-- CLOSE!
# Emmetropia   | 0.2409       | 0.4773       | 0.2818 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.15      0.50      0.24        20
#       Myopia       0.61      0.45      0.52        97
#    Hyperopia       0.07      0.03      0.04        35
#
#     accuracy                           0.36       152
#    macro avg       0.28      0.33      0.27       152
# weighted avg       0.43      0.36      0.37       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.3618 (36.18%)
# Precision (Weighted): 0.4256
# Recall (Weighted)   : 0.3618
# F1 Score (Weighted) : 0.3725
#
# --- Fold 5/10 ---
# Epoch 1/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.4098 - loss: 0.6971
# Epoch 1: val_loss improved from None to 0.38682, saving model to best_efficientnet_fold_5.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_5.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 88s 562ms/step - accuracy: 0.4568 - loss: 0.5872 - val_accuracy: 0.6354 - val_loss: 0.3868
# Epoch 2/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.5370 - loss: 0.4713
# Epoch 2: val_loss improved from 0.38682 to 0.35198, saving model to best_efficientnet_fold_5.h5
#
# Epoch 2: finished saving model to best_efficientnet_fold_5.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 443ms/step - accuracy: 0.5618 - loss: 0.4612 - val_accuracy: 0.6042 - val_loss: 0.3520
# Epoch 3/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.5839 - loss: 0.4370
# Epoch 3: val_loss did not improve from 0.35198
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.5831 - loss: 0.4443 - val_accuracy: 0.6250 - val_loss: 0.3849
# Epoch 4/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.5846 - loss: 0.4255
# Epoch 4: val_loss did not improve from 0.35198
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 432ms/step - accuracy: 0.6077 - loss: 0.4077 - val_accuracy: 0.6354 - val_loss: 0.3666
# Epoch 5/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.6252 - loss: 0.4231
# Epoch 5: val_loss improved from 0.35198 to 0.29955, saving model to best_efficientnet_fold_5.h5
#
# Epoch 5: finished saving model to best_efficientnet_fold_5.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6270 - loss: 0.4067 - val_accuracy: 0.7083 - val_loss: 0.2996
# Epoch 6/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.6350 - loss: 0.3991
# Epoch 6: val_loss did not improve from 0.29955
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 39s 421ms/step - accuracy: 0.6283 - loss: 0.3967 - val_accuracy: 0.6458 - val_loss: 0.3180
# Epoch 7/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6777 - loss: 0.3581
# Epoch 7: val_loss did not improve from 0.29955
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.6749 - loss: 0.3621 - val_accuracy: 0.6250 - val_loss: 0.3514
# Epoch 8/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6649 - loss: 0.3648
# Epoch 8: val_loss did not improve from 0.29955
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.6722 - loss: 0.3632 - val_accuracy: 0.6354 - val_loss: 0.3239
# Epoch 9/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.6722 - loss: 0.3410
# Epoch 9: val_loss improved from 0.29955 to 0.29667, saving model to best_efficientnet_fold_5.h5
#
# Epoch 9: finished saving model to best_efficientnet_fold_5.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 439ms/step - accuracy: 0.6729 - loss: 0.3503 - val_accuracy: 0.6562 - val_loss: 0.2967
# Epoch 10/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.6956 - loss: 0.3374
# Epoch 10: val_loss improved from 0.29667 to 0.24843, saving model to best_efficientnet_fold_5.h5
#
# Epoch 10: finished saving model to best_efficientnet_fold_5.h5
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6888 - loss: 0.3453 - val_accuracy: 0.6979 - val_loss: 0.2484
# Epoch 11/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.6921 - loss: 0.3321
# Epoch 11: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 425ms/step - accuracy: 0.6882 - loss: 0.3385 - val_accuracy: 0.6771 - val_loss: 0.3072
# Epoch 12/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7009 - loss: 0.3195
# Epoch 12: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 431ms/step - accuracy: 0.7028 - loss: 0.3245 - val_accuracy: 0.7083 - val_loss: 0.2806
# Epoch 13/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.6891 - loss: 0.3391
# Epoch 13: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.6948 - loss: 0.3286 - val_accuracy: 0.6771 - val_loss: 0.3081
# Epoch 14/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.7114 - loss: 0.3280
# Epoch 14: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 438ms/step - accuracy: 0.7055 - loss: 0.3356 - val_accuracy: 0.6667 - val_loss: 0.2924
# Epoch 15/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.6944 - loss: 0.3153
# Epoch 15: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6975 - loss: 0.3093 - val_accuracy: 0.6146 - val_loss: 0.3422
# Epoch 16/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.7035 - loss: 0.3084
# Epoch 16: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 44s 471ms/step - accuracy: 0.7154 - loss: 0.3015 - val_accuracy: 0.6979 - val_loss: 0.2991
# Epoch 17/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.7166 - loss: 0.3184
# Epoch 17: val_loss did not improve from 0.24843
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.7134 - loss: 0.3192 - val_accuracy: 0.7500 - val_loss: 0.2766
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 10.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 246ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Emmetropia   | 0.6432       | 0.0630       | 0.2937
# Myopia       | 0.0615       | 0.6649       | 0.2736
# Hyperopia    | 0.0861       | 0.5821       | 0.3318
# Hyperopia    | 0.1053       | 0.7575       | 0.1372
# Emmetropia   | 0.3475       | 0.0888       | 0.5637
# Emmetropia   | 0.4542       | 0.0971       | 0.4487
# Myopia       | 0.0615       | 0.7877       | 0.1508
# Hyperopia    | 0.2707       | 0.5720       | 0.1573
# Myopia       | 0.1455       | 0.6499       | 0.2046
# Myopia       | 0.1692       | 0.3889       | 0.4419
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.6432       | 0.0630       | 0.2937 <-- CLOSE!
# Emmetropia   | 0.3475       | 0.0888       | 0.5637 <-- CLOSE!
# Emmetropia   | 0.4542       | 0.0971       | 0.4487 <-- CLOSE!
# Emmetropia   | 0.0624       | 0.7942       | 0.1433
# Emmetropia   | 0.1336       | 0.7341       | 0.1323
# Emmetropia   | 0.1951       | 0.3184       | 0.4865
# Emmetropia   | 0.0733       | 0.7330       | 0.1937
# Emmetropia   | 0.5762       | 0.0762       | 0.3476 <-- CLOSE!
# Emmetropia   | 0.1692       | 0.3889       | 0.4419
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.12      0.33      0.17         9
#       Myopia       0.67      0.55      0.60        62
#    Hyperopia       0.08      0.05      0.06        19
#
#     accuracy                           0.42        90
#    macro avg       0.29      0.31      0.28        90
# weighted avg       0.49      0.42      0.44        90
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4222 (42.22%)
# Precision (Weighted): 0.4870
# Recall (Weighted)   : 0.4222
# F1 Score (Weighted) : 0.4449
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 308ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.0483       | 0.8361       | 0.1156
# Hyperopia    | 0.1727       | 0.6992       | 0.1281
# Emmetropia   | 0.0540       | 0.8096       | 0.1364
# Myopia       | 0.0677       | 0.7777       | 0.1546
# Hyperopia    | 0.0680       | 0.8298       | 0.1022
# Myopia       | 0.4540       | 0.1058       | 0.4402
# Hyperopia    | 0.5746       | 0.0514       | 0.3739
# Emmetropia   | 0.0655       | 0.7646       | 0.1700
# Hyperopia    | 0.5149       | 0.0779       | 0.4071
# Emmetropia   | 0.0726       | 0.7862       | 0.1412
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.0540       | 0.8096       | 0.1364
# Emmetropia   | 0.0655       | 0.7646       | 0.1700
# Emmetropia   | 0.0726       | 0.7862       | 0.1412
# Emmetropia   | 0.5187       | 0.0724       | 0.4089 <-- CLOSE!
# Emmetropia   | 0.0423       | 0.8122       | 0.1455
# Emmetropia   | 0.0978       | 0.6281       | 0.2741
# Emmetropia   | 0.0937       | 0.8006       | 0.1057
# Emmetropia   | 0.4649       | 0.0681       | 0.4670 <-- CLOSE!
# Emmetropia   | 0.5157       | 0.0583       | 0.4260 <-- CLOSE!
# Emmetropia   | 0.4213       | 0.1290       | 0.4498 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.05      0.10      0.07        20
#       Myopia       0.60      0.44      0.51        97
#    Hyperopia       0.25      0.29      0.27        35
#
#     accuracy                           0.36       152
#    macro avg       0.30      0.28      0.28       152
# weighted avg       0.45      0.36      0.39       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.3618 (36.18%)
# Precision (Weighted): 0.4453
# Recall (Weighted)   : 0.3618
# F1 Score (Weighted) : 0.3949
#
# --- Fold 6/10 ---
# Epoch 1/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.4225 - loss: 0.6855
# Epoch 1: val_loss improved from None to 0.35248, saving model to best_efficientnet_fold_6.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_6.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 92s 573ms/step - accuracy: 0.4684 - loss: 0.5808 - val_accuracy: 0.6042 - val_loss: 0.3525
# Epoch 2/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.5043 - loss: 0.5262
# Epoch 2: val_loss improved from 0.35248 to 0.31941, saving model to best_efficientnet_fold_6.h5
#
# Epoch 2: finished saving model to best_efficientnet_fold_6.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 44s 454ms/step - accuracy: 0.5335 - loss: 0.5050 - val_accuracy: 0.6354 - val_loss: 0.3194
# Epoch 3/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.5962 - loss: 0.4522
# Epoch 3: val_loss improved from 0.31941 to 0.30059, saving model to best_efficientnet_fold_6.h5
#
# Epoch 3: finished saving model to best_efficientnet_fold_6.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 43s 444ms/step - accuracy: 0.5863 - loss: 0.4547 - val_accuracy: 0.6771 - val_loss: 0.3006
# Epoch 4/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6136 - loss: 0.4272
# Epoch 4: val_loss did not improve from 0.30059
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 429ms/step - accuracy: 0.6076 - loss: 0.4309 - val_accuracy: 0.6354 - val_loss: 0.3306
# Epoch 5/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.6164 - loss: 0.4220
# Epoch 5: val_loss improved from 0.30059 to 0.28306, saving model to best_efficientnet_fold_6.h5
#
# Epoch 5: finished saving model to best_efficientnet_fold_6.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 44s 453ms/step - accuracy: 0.6186 - loss: 0.4189 - val_accuracy: 0.6667 - val_loss: 0.2831
# Epoch 6/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6206 - loss: 0.4035
# Epoch 6: val_loss improved from 0.28306 to 0.24077, saving model to best_efficientnet_fold_6.h5
#
# Epoch 6: finished saving model to best_efficientnet_fold_6.h5
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 42s 437ms/step - accuracy: 0.6398 - loss: 0.3933 - val_accuracy: 0.7396 - val_loss: 0.2408
# Epoch 7/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.6555 - loss: 0.3842
# Epoch 7: val_loss did not improve from 0.24077
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 41s 430ms/step - accuracy: 0.6437 - loss: 0.3791 - val_accuracy: 0.7604 - val_loss: 0.2775
# Epoch 8/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.6422 - loss: 0.4048
# Epoch 8: val_loss did not improve from 0.24077
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 42s 439ms/step - accuracy: 0.6508 - loss: 0.3906 - val_accuracy: 0.6979 - val_loss: 0.2598
# Epoch 9/30
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.6611 - loss: 0.3931
# Epoch 9: val_loss did not improve from 0.24077
# ...
# Epoch 15: val_loss did not improve from 0.23482
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.7020 - loss: 0.3227 - val_accuracy: 0.7083 - val_loss: 0.2965
# Epoch 16/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7137 - loss: 0.3200
# Epoch 16: val_loss did not improve from 0.23482
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.7171 - loss: 0.3087 - val_accuracy: 0.7188 - val_loss: 0.2627
# Epoch 17/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.7209 - loss: 0.3092
# Epoch 17: val_loss did not improve from 0.23482
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 432ms/step - accuracy: 0.7191 - loss: 0.3089 - val_accuracy: 0.6875 - val_loss: 0.3110
# Epoch 18/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.7166 - loss: 0.2987
# Epoch 18: val_loss improved from 0.23482 to 0.20836, saving model to best_efficientnet_fold_9.h5
#
# Epoch 18: finished saving model to best_efficientnet_fold_9.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 448ms/step - accuracy: 0.7329 - loss: 0.2996 - val_accuracy: 0.7917 - val_loss: 0.2084
# Epoch 19/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.7074 - loss: 0.3095
# Epoch 19: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 430ms/step - accuracy: 0.7138 - loss: 0.3040 - val_accuracy: 0.7396 - val_loss: 0.3144
# Epoch 20/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.7120 - loss: 0.3115
# Epoch 20: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 434ms/step - accuracy: 0.7375 - loss: 0.2975 - val_accuracy: 0.7292 - val_loss: 0.3299
# Epoch 21/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.7200 - loss: 0.3048
# Epoch 21: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.7355 - loss: 0.2891 - val_accuracy: 0.7188 - val_loss: 0.2384
# Epoch 22/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.7511 - loss: 0.2821
# Epoch 22: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 434ms/step - accuracy: 0.7526 - loss: 0.2860 - val_accuracy: 0.7604 - val_loss: 0.2203
# Epoch 23/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.7468 - loss: 0.2761
# Epoch 23: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 429ms/step - accuracy: 0.7289 - loss: 0.2820 - val_accuracy: 0.6667 - val_loss: 0.3845
# Epoch 24/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7405 - loss: 0.2675
# Epoch 24: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.7539 - loss: 0.2680 - val_accuracy: 0.6458 - val_loss: 0.3924
# Epoch 25/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7287 - loss: 0.2805
# Epoch 25: val_loss did not improve from 0.20836
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 432ms/step - accuracy: 0.7355 - loss: 0.2839 - val_accuracy: 0.6875 - val_loss: 0.2603
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 18.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 264ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Hyperopia    | 0.0356       | 0.8649       | 0.0995
# Myopia       | 0.0239       | 0.8942       | 0.0819
# Myopia       | 0.3627       | 0.1045       | 0.5329
# Myopia       | 0.0506       | 0.8016       | 0.1478
# Myopia       | 0.0300       | 0.9165       | 0.0536
# Hyperopia    | 0.2221       | 0.6380       | 0.1399
# Emmetropia   | 0.4486       | 0.1077       | 0.4437
# Emmetropia   | 0.0296       | 0.8803       | 0.0901
# Hyperopia    | 0.3851       | 0.1356       | 0.4793
# Hyperopia    | 0.3135       | 0.1181       | 0.5683
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.4486       | 0.1077       | 0.4437 <-- CLOSE!
# Emmetropia   | 0.0296       | 0.8803       | 0.0901
# Emmetropia   | 0.3549       | 0.0955       | 0.5496 <-- CLOSE!
# Emmetropia   | 0.0168       | 0.9174       | 0.0658
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.07      0.25      0.11         4
#       Myopia       0.68      0.58      0.62        59
#    Hyperopia       0.38      0.36      0.37        25
#
#     accuracy                           0.50        88
#    macro avg       0.38      0.40      0.37        88
# weighted avg       0.57      0.50      0.53        88
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.5000 (50.00%)
# Precision (Weighted): 0.5657
# Recall (Weighted)   : 0.5000
# F1 Score (Weighted) : 0.5277
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 292ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.2841       | 0.0995       | 0.6164
# Hyperopia    | 0.4827       | 0.0812       | 0.4362
# Emmetropia   | 0.0290       | 0.8871       | 0.0839
# Myopia       | 0.5234       | 0.0578       | 0.4189
# Hyperopia    | 0.4692       | 0.0706       | 0.4602
# Myopia       | 0.2984       | 0.1642       | 0.5374
# Hyperopia    | 0.3635       | 0.1223       | 0.5143
# Emmetropia   | 0.3931       | 0.1020       | 0.5050
# Hyperopia    | 0.0225       | 0.8779       | 0.0996
# Emmetropia   | 0.0367       | 0.8607       | 0.1026
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.0290       | 0.8871       | 0.0839
# Emmetropia   | 0.3931       | 0.1020       | 0.5050 <-- CLOSE!
# Emmetropia   | 0.0367       | 0.8607       | 0.1026
# Emmetropia   | 0.0140       | 0.9066       | 0.0794
# Emmetropia   | 0.1319       | 0.7734       | 0.0947
# Emmetropia   | 0.0480       | 0.6354       | 0.3166
# Emmetropia   | 0.1590       | 0.7481       | 0.0929
# Emmetropia   | 0.0185       | 0.9064       | 0.0751
# Emmetropia   | 0.3965       | 0.1623       | 0.4412 <-- CLOSE!
# Emmetropia   | 0.0379       | 0.7645       | 0.1976
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.11      0.15      0.13        20
#       Myopia       0.64      0.51      0.57        97
#    Hyperopia       0.33      0.46      0.38        35
#
#     accuracy                           0.45       152
#    macro avg       0.36      0.37      0.36       152
# weighted avg       0.50      0.45      0.47       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4474 (44.74%)
# Precision (Weighted): 0.5013
# Recall (Weighted)   : 0.4474
# F1 Score (Weighted) : 0.4660
#
# --- Fold 10/10 ---
# Epoch 1/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.3977 - loss: 0.7237
# Epoch 1: val_loss improved from None to 0.39390, saving model to best_efficientnet_fold_10.h5
#
# Epoch 1: finished saving model to best_efficientnet_fold_10.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 90s 580ms/step - accuracy: 0.4480 - loss: 0.6160 - val_accuracy: 0.6042 - val_loss: 0.3939
# Epoch 2/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.5206 - loss: 0.5182
# Epoch 2: val_loss improved from 0.39390 to 0.38027, saving model to best_efficientnet_fold_10.h5
#
# Epoch 2: finished saving model to best_efficientnet_fold_10.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 43s 461ms/step - accuracy: 0.5296 - loss: 0.5038 - val_accuracy: 0.5938 - val_loss: 0.3803
# Epoch 3/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.5822 - loss: 0.4628
# Epoch 3: val_loss improved from 0.38027 to 0.30509, saving model to best_efficientnet_fold_10.h5
#
# Epoch 3: finished saving model to best_efficientnet_fold_10.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 445ms/step - accuracy: 0.5855 - loss: 0.4445 - val_accuracy: 0.8021 - val_loss: 0.3051
# Epoch 4/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.6420 - loss: 0.4009
# Epoch 4: val_loss improved from 0.30509 to 0.27858, saving model to best_efficientnet_fold_10.h5
#
# Epoch 4: finished saving model to best_efficientnet_fold_10.h5
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 437ms/step - accuracy: 0.6276 - loss: 0.4148 - val_accuracy: 0.6979 - val_loss: 0.2786
# Epoch 5/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.6219 - loss: 0.4129
# Epoch 5: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.6191 - loss: 0.4060 - val_accuracy: 0.6458 - val_loss: 0.4081
# Epoch 6/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.6327 - loss: 0.4301
# Epoch 6: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 442ms/step - accuracy: 0.6401 - loss: 0.4124 - val_accuracy: 0.6146 - val_loss: 0.3611
# Epoch 7/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.6386 - loss: 0.3829
# Epoch 7: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 448ms/step - accuracy: 0.6513 - loss: 0.3839 - val_accuracy: 0.6979 - val_loss: 0.3541
# Epoch 8/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.6280 - loss: 0.3832
# Epoch 8: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6461 - loss: 0.3754 - val_accuracy: 0.6667 - val_loss: 0.3075
# Epoch 9/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.6594 - loss: 0.3807
# Epoch 9: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 451ms/step - accuracy: 0.6566 - loss: 0.3876 - val_accuracy: 0.7188 - val_loss: 0.3417
# Epoch 10/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.6814 - loss: 0.3538
# Epoch 10: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 41s 440ms/step - accuracy: 0.6724 - loss: 0.3623 - val_accuracy: 0.7396 - val_loss: 0.3305
# Epoch 11/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6738 - loss: 0.3643
# Epoch 11: val_loss did not improve from 0.27858
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 42s 442ms/step - accuracy: 0.6875 - loss: 0.3486 - val_accuracy: 0.7188 - val_loss: 0.3213
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 4.
#
# [Validation Set Evaluation]
#
# --- Running Inference ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 248ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Emmetropia   | 0.3738       | 0.1278       | 0.4985
# Myopia       | 0.5194       | 0.0790       | 0.4016
# Myopia       | 0.1132       | 0.5975       | 0.2893
# Myopia       | 0.5440       | 0.0941       | 0.3619
# Emmetropia   | 0.1757       | 0.5836       | 0.2407
# Myopia       | 0.5501       | 0.0736       | 0.3763
# Hyperopia    | 0.1241       | 0.6357       | 0.2402
# Emmetropia   | 0.4438       | 0.0898       | 0.4664
# Hyperopia    | 0.1015       | 0.6283       | 0.2702
# Myopia       | 0.4719       | 0.1055       | 0.4225
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.3738       | 0.1278       | 0.4985 <-- CLOSE!
# Emmetropia   | 0.1757       | 0.5836       | 0.2407
# Emmetropia   | 0.4438       | 0.0898       | 0.4664 <-- CLOSE!
# Emmetropia   | 0.1063       | 0.5589       | 0.3348
# Emmetropia   | 0.1450       | 0.6016       | 0.2535
# Emmetropia   | 0.1798       | 0.5561       | 0.2641
# Emmetropia   | 0.4585       | 0.0860       | 0.4555 <-- CLOSE!
# Emmetropia   | 0.1063       | 0.5589       | 0.3348
# Emmetropia   | 0.1015       | 0.6283       | 0.2702
# Emmetropia   | 0.1272       | 0.5918       | 0.2810
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.05      0.10      0.07        10
#       Myopia       0.62      0.55      0.58        58
#    Hyperopia       0.18      0.15      0.16        20
#
#     accuracy                           0.41        88
#    macro avg       0.28      0.27      0.27        88
# weighted avg       0.45      0.41      0.43        88
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.4091 (40.91%)
# Precision (Weighted): 0.4517
# Recall (Weighted)   : 0.4091
# F1 Score (Weighted) : 0.4282
#
# [Holdout Test Set Evaluation]
#
# --- Running Inference ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step
#
# --- Raw Probabilities: First 10 Images ---
# True Label   | Emmetropia   | Myopia       | {'Hyperopia':<12}
# -------------------------------------------------------
# Myopia       | 0.4856       | 0.0899       | 0.4245
# Hyperopia    | 0.1179       | 0.5581       | 0.3240
# Emmetropia   | 0.0854       | 0.6868       | 0.2278
# Myopia       | 0.5326       | 0.0859       | 0.3815
# Hyperopia    | 0.1525       | 0.5695       | 0.2780
# Myopia       | 0.4632       | 0.0701       | 0.4667
# Hyperopia    | 0.1000       | 0.6697       | 0.2304
# Emmetropia   | 0.0997       | 0.5949       | 0.3055
# Hyperopia    | 0.5116       | 0.0805       | 0.4079
# Emmetropia   | 0.1024       | 0.6596       | 0.2380
#
# --- Raw Probabilities: ACTUAL Emmetropia Images ---
# True Label   | Emmetropia   | Myopia       |Hyperopia
# -------------------------------------------------------
# Emmetropia   | 0.0854       | 0.6868       | 0.2278
# Emmetropia   | 0.0997       | 0.5949       | 0.3055
# Emmetropia   | 0.1024       | 0.6596       | 0.2380
# Emmetropia   | 0.4895       | 0.0882       | 0.4222 <-- CLOSE!
# Emmetropia   | 0.0824       | 0.7020       | 0.2156
# Emmetropia   | 0.5076       | 0.0844       | 0.4081 <-- CLOSE!
# Emmetropia   | 0.1303       | 0.6521       | 0.2176
# Emmetropia   | 0.1479       | 0.5870       | 0.2651
# Emmetropia   | 0.3792       | 0.0924       | 0.5284 <-- CLOSE!
# Emmetropia   | 0.5015       | 0.0854       | 0.4132 <-- CLOSE!
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#   Emmetropia       0.10      0.25      0.14        20
#       Myopia       0.60      0.45      0.52        97
#    Hyperopia       0.15      0.11      0.13        35
#
#     accuracy                           0.35       152
#    macro avg       0.28      0.27      0.26       152
# weighted avg       0.43      0.35      0.38       152
#
#
# --- Evaluation Metrics ---
#
# Accuracy         : 0.3487 (34.87%)
# Precision (Weighted): 0.4314
# Recall (Weighted)   : 0.3487
# F1 Score (Weighted) : 0.3783
#
# =================================================================
#     FINAL CROSS-VALIDATION SUMMARY (10-FOLD AVERAGE)
# =================================================================
#
# --- Validation Performance (Averaged across Folds) ---
# Accuracy    : 0.4240 ± 0.0651
# Precision   : 0.4793 ± 0.0685
# Recall      : 0.4240 ± 0.0651
# F1          : 0.4443 ± 0.0651
#
# --- Per-Fold Validation Breakdown ---
#    Fold  Accuracy  Precision   Recall  F1 Score
#  Fold 1  0.337209   0.384012 0.337209  0.357317
#  Fold 2  0.534091   0.609658 0.534091  0.560546
#  Fold 3  0.477273   0.512574 0.477273  0.491113
#  Fold 4  0.416667   0.452857 0.416667  0.421053
#  Fold 5  0.422222   0.487037 0.422222  0.444890
#  Fold 6  0.388235   0.407016 0.388235  0.395562
#  Fold 7  0.441860   0.510261 0.441860  0.464903
#  Fold 8  0.313253   0.411787 0.313253  0.351868
#  Fold 9  0.500000   0.565690 0.500000  0.527676
# Fold 10  0.409091   0.451682 0.409091  0.428163
#
# -----------------------------------------------------------------
#
# --- Holdout Test Performance (Averaged across Fold Models) ---
# Accuracy    : 0.4086 ± 0.0395
# Precision   : 0.4761 ± 0.0351
# Recall      : 0.4086 ± 0.0395
# F1          : 0.4321 ± 0.0381
#
# --- Per-Fold Holdout Test Breakdown ---
#    Fold  Accuracy  Precision   Recall  F1 Score
#  Fold 1  0.388158   0.448643 0.388158  0.412558
#  Fold 2  0.414474   0.462361 0.414474  0.434436
#  Fold 3  0.460526   0.518276 0.460526  0.482058
#  Fold 4  0.361842   0.425579 0.361842  0.372466
#  Fold 5  0.361842   0.445267 0.361842  0.394919
#  Fold 6  0.447368   0.502322 0.447368  0.462809
#  Fold 7  0.447368   0.507057 0.447368  0.470750
#  Fold 8  0.407895   0.519017 0.407895  0.446522
#  Fold 9  0.447368   0.501252 0.447368  0.466016
# Fold 10  0.348684   0.431408 0.348684  0.378327
# =================================================================
